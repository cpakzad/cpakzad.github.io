# %%
#### SP500 + EUR + GR + JP + BTC + BTC_reduced
X1_2010_SP=pd.read_csv('DAT_ASCII_SPXUSD_M1_2010.csv',sep=';',header=None)
X1_2011_SP=pd.read_csv('DAT_ASCII_SPXUSD_M1_2011.csv',sep=';',header=None)
X1_2012_SP=pd.read_csv('DAT_ASCII_SPXUSD_M1_2012.csv',sep=';',header=None)
X1_2013_SP=pd.read_csv('DAT_ASCII_SPXUSD_M1_2013.csv',sep=';',header=None)
X1_2014_SP=pd.read_csv('DAT_ASCII_SPXUSD_M1_2014.csv',sep=';',header=None)
X1_2015_SP=pd.read_csv('DAT_ASCII_SPXUSD_M1_2015.csv',sep=';',header=None)
X1_2016_SP=pd.read_csv('DAT_ASCII_SPXUSD_M1_2016.csv',sep=';',header=None)
X1_2017_SP=pd.read_csv('DAT_ASCII_SPXUSD_M1_2017.csv',sep=';',header=None)
X1_2018_SP=pd.read_csv('DAT_ASCII_SPXUSD_M1_2018.csv',sep=';',header=None)
#X1_2010_SP=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\SPXUSD\DAT_ASCII_SPXUSD_M1_2010.csv',sep=';',header=None)
#X1_2011_SP=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\SPXUSD\DAT_ASCII_SPXUSD_M1_2011.csv',sep=';',header=None)
#X1_2012_SP=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\SPXUSD\DAT_ASCII_SPXUSD_M1_2012.csv',sep=';',header=None)
#X1_2013_SP=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\SPXUSD\DAT_ASCII_SPXUSD_M1_2013.csv',sep=';',header=None)
#X1_2014_SP=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\SPXUSD\DAT_ASCII_SPXUSD_M1_2014.csv',sep=';',header=None)
#X1_2015_SP=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\SPXUSD\DAT_ASCII_SPXUSD_M1_2015.csv',sep=';',header=None)
#X1_2016_SP=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\SPXUSD\DAT_ASCII_SPXUSD_M1_2016.csv',sep=';',header=None)
#X1_2017_SP=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\SPXUSD\DAT_ASCII_SPXUSD_M1_2017.csv',sep=';',header=None)
#X1_2018_SP=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\SPXUSD\DAT_ASCII_SPXUSD_M1_2018.csv',sep=';',header=None)
X_2010_SP = ((X1_2010_SP.values)[:,4]).astype(float)
X_2011_SP = ((X1_2011_SP.values)[:,4]).astype(float)
X_2012_SP = ((X1_2012_SP.values)[:,4]).astype(float)
X_2013_SP = ((X1_2013_SP.values)[:,4]).astype(float)
X_2014_SP = ((X1_2014_SP.values)[:,4]).astype(float)
X_2015_SP = ((X1_2015_SP.values)[:,4]).astype(float)
X_2016_SP = ((X1_2016_SP.values)[:,4]).astype(float)
X_2017_SP = ((X1_2017_SP.values)[:,4]).astype(float)
X_2018_SP = ((X1_2018_SP.values)[:,4]).astype(float)
X_conc_SP=np.append(X_2010_SP,X_2011_SP)
X_conc_SP=np.append(X_conc_SP,X_2012_SP)
X_conc_SP=np.append(X_conc_SP,X_2013_SP)
X_conc_SP=np.append(X_conc_SP,X_2014_SP)
X_conc_SP=np.append(X_conc_SP,X_2015_SP)
X_conc_SP=np.append(X_conc_SP,X_2016_SP)
X_conc_SP=np.append(X_conc_SP,X_2017_SP)
X_conc_SP=np.append(X_conc_SP,X_2018_SP)

X_hour_SP= X_conc_SP[np.arange(0,X_conc_SP.shape[0]-60,60)] # conversion minutes vers heures
X_logreturn1_SP=np.diff(np.log(X_hour_SP)) # shape -1
X_logreturn2_SP = np.append(X_logreturn1_SP[0],X_logreturn1_SP) # shape +1
X_temp_SP = (X_logreturn2_SP[:24*int(X_logreturn2_SP.shape[0]/24)]).reshape((int(X_logreturn2_SP.shape[0]/24),24))
Y_SP = np.max(X_temp_SP,axis=1)[np.arange(0,X_temp_SP.shape[0],2)]
X_SP = X_temp_SP[np.arange(0,X_temp_SP.shape[0],2),:]

X_SP=np.expand_dims(X_SP,axis=0) # shape (N,n,d) with N=1;n=735;d=24
Y_SP=np.expand_dims(Y_SP,axis=0) # shape (N,n,d) with N=1;n=735;d=24
##############################
X1_2010_EUR=pd.read_csv('DAT_ASCII_ETXEUR_M1_2010.csv',sep=';',header=None)
X1_2011_EUR=pd.read_csv('DAT_ASCII_ETXEUR_M1_2011.csv',sep=';',header=None)
X1_2012_EUR=pd.read_csv('DAT_ASCII_ETXEUR_M1_2012.csv',sep=';',header=None)
X1_2013_EUR=pd.read_csv('DAT_ASCII_ETXEUR_M1_2013.csv',sep=';',header=None)
X1_2014_EUR=pd.read_csv('DAT_ASCII_ETXEUR_M1_2014.csv',sep=';',header=None)
X1_2015_EUR=pd.read_csv('DAT_ASCII_ETXEUR_M1_2015.csv',sep=';',header=None)
X1_2016_EUR=pd.read_csv('DAT_ASCII_ETXEUR_M1_2016.csv',sep=';',header=None)
X1_2017_EUR=pd.read_csv('DAT_ASCII_ETXEUR_M1_2017.csv',sep=';',header=None)
X1_2018_EUR=pd.read_csv('DAT_ASCII_ETXEUR_M1_2018.csv',sep=';',header=None)

#X1_2010_EUR=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\ETXEUR\DAT_ASCII_ETXEUR_M1_2010.csv',sep=';',header=None)
#X1_2011_EUR=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\ETXEUR\DAT_ASCII_ETXEUR_M1_2011.csv',sep=';',header=None)
#X1_2012_EUR=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\ETXEUR\DAT_ASCII_ETXEUR_M1_2012.csv',sep=';',header=None)
#X1_2013_EUR=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\ETXEUR\DAT_ASCII_ETXEUR_M1_2013.csv',sep=';',header=None)
#X1_2014_EUR=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\ETXEUR\DAT_ASCII_ETXEUR_M1_2014.csv',sep=';',header=None)
#X1_2015_EUR=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\ETXEUR\DAT_ASCII_ETXEUR_M1_2015.csv',sep=';',header=None)
#X1_2016_EUR=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\ETXEUR\DAT_ASCII_ETXEUR_M1_2016.csv',sep=';',header=None)
#X1_2017_EUR=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\ETXEUR\DAT_ASCII_ETXEUR_M1_2017.csv',sep=';',header=None)
#X1_2018_EUR=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\ETXEUR\DAT_ASCII_ETXEUR_M1_2018.csv',sep=';',header=None)

X_2010_EUR = ((X1_2010_EUR.values)[:,4]).astype(float)
X_2011_EUR = ((X1_2011_EUR.values)[:,4]).astype(float)
X_2012_EUR = ((X1_2012_EUR.values)[:,4]).astype(float)
X_2013_EUR = ((X1_2013_EUR.values)[:,4]).astype(float)
X_2014_EUR = ((X1_2014_EUR.values)[:,4]).astype(float)
X_2015_EUR = ((X1_2015_EUR.values)[:,4]).astype(float)
X_2016_EUR = ((X1_2016_EUR.values)[:,4]).astype(float)
X_2017_EUR = ((X1_2017_EUR.values)[:,4]).astype(float)
X_2018_EUR = ((X1_2018_EUR.values)[:,4]).astype(float)
X_conc_EUR=np.append(X_2010_EUR,X_2011_EUR)
X_conc_EUR=np.append(X_conc_EUR,X_2012_EUR)
X_conc_EUR=np.append(X_conc_EUR,X_2013_EUR)
X_conc_EUR=np.append(X_conc_EUR,X_2014_EUR)
X_conc_EUR=np.append(X_conc_EUR,X_2015_EUR)
X_conc_EUR=np.append(X_conc_EUR,X_2016_EUR)
X_conc_EUR=np.append(X_conc_EUR,X_2017_EUR)
X_conc_EUR=np.append(X_conc_EUR,X_2018_EUR)

X_hour_EUR= X_conc_EUR[np.arange(0,X_conc_EUR.shape[0]-60,60)] # conversion minutes vers heures
X_logreturn1_EUR=np.diff(np.log(X_hour_EUR)) # shape -1
X_logreturn2_EUR = np.append(X_logreturn1_EUR[0],X_logreturn1_EUR) # shape +1
X_temp_EUR = (X_logreturn2_EUR[:24*int(X_logreturn2_EUR.shape[0]/24)]).reshape((int(X_logreturn2_EUR.shape[0]/24),24))
Y_EUR = np.max(X_temp_EUR,axis=1)[np.arange(0,X_temp_EUR.shape[0],2)]
X_EUR = X_temp_EUR[np.arange(0,X_temp_EUR.shape[0],2),:]

X_EUR=np.expand_dims(X_EUR,axis=0) # shape (N,n,d) with N=1;n=735;d=24
Y_EUR=np.expand_dims(Y_EUR,axis=0) # shape (N,n,d) with N=1;n=735;d=24

##############################
X1_2010_GR=pd.read_csv('DAT_ASCII_GRXEUR_M1_2010.csv',sep=';',header=None)
X1_2011_GR=pd.read_csv('DAT_ASCII_GRXEUR_M1_2011.csv',sep=';',header=None)
X1_2012_GR=pd.read_csv('DAT_ASCII_GRXEUR_M1_2012.csv',sep=';',header=None)
X1_2013_GR=pd.read_csv('DAT_ASCII_GRXEUR_M1_2013.csv',sep=';',header=None)
X1_2014_GR=pd.read_csv('DAT_ASCII_GRXEUR_M1_2014.csv',sep=';',header=None)
X1_2015_GR=pd.read_csv('DAT_ASCII_GRXEUR_M1_2015.csv',sep=';',header=None)
X1_2016_GR=pd.read_csv('DAT_ASCII_GRXEUR_M1_2016.csv',sep=';',header=None)
X1_2017_GR=pd.read_csv('DAT_ASCII_GRXEUR_M1_2017.csv',sep=';',header=None)
X1_2018_GR=pd.read_csv('DAT_ASCII_GRXEUR_M1_2018.csv',sep=';',header=None)

#X1_2010_GR=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\GRXEUR\DAT_ASCII_GRXEUR_M1_2010.csv',sep=';',header=None)
#X1_2011_GR=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\GRXEUR\DAT_ASCII_GRXEUR_M1_2011.csv',sep=';',header=None)
#X1_2012_GR=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\GRXEUR\DAT_ASCII_GRXEUR_M1_2012.csv',sep=';',header=None)
#X1_2013_GR=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\GRXEUR\DAT_ASCII_GRXEUR_M1_2013.csv',sep=';',header=None)
#X1_2014_GR=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\GRXEUR\DAT_ASCII_GRXEUR_M1_2014.csv',sep=';',header=None)
#X1_2015_GR=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\GRXEUR\DAT_ASCII_GRXEUR_M1_2015.csv',sep=';',header=None)
#X1_2016_GR=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\GRXEUR\DAT_ASCII_GRXEUR_M1_2016.csv',sep=';',header=None)
#X1_2017_GR=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\GRXEUR\DAT_ASCII_GRXEUR_M1_2017.csv',sep=';',header=None)
#X1_2018_GR=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\GRXEUR\DAT_ASCII_GRXEUR_M1_2018.csv',sep=';',header=None)

X_2010_GR = ((X1_2010_GR.values)[:,4]).astype(float)
X_2011_GR = ((X1_2011_GR.values)[:,4]).astype(float)
X_2012_GR = ((X1_2012_GR.values)[:,4]).astype(float)
X_2013_GR = ((X1_2013_GR.values)[:,4]).astype(float)
X_2014_GR = ((X1_2014_GR.values)[:,4]).astype(float)
X_2015_GR = ((X1_2015_GR.values)[:,4]).astype(float)
X_2016_GR = ((X1_2016_GR.values)[:,4]).astype(float)
X_2017_GR = ((X1_2017_GR.values)[:,4]).astype(float)
X_2018_GR = ((X1_2018_GR.values)[:,4]).astype(float)
X_conc_GR=np.append(X_2010_GR,X_2011_GR)
X_conc_GR=np.append(X_conc_GR,X_2012_GR)
X_conc_GR=np.append(X_conc_GR,X_2013_GR)
X_conc_GR=np.append(X_conc_GR,X_2014_GR)
X_conc_GR=np.append(X_conc_GR,X_2015_GR)
X_conc_GR=np.append(X_conc_GR,X_2016_GR)
X_conc_GR=np.append(X_conc_GR,X_2017_GR)
X_conc_GR=np.append(X_conc_GR,X_2018_GR)

X_hour_GR= X_conc_GR[np.arange(0,X_conc_GR.shape[0]-60,60)] # conversion minutes vers hGRes
X_logreturn1_GR=np.diff(np.log(X_hour_GR)) # shape -1
X_logreturn2_GR = np.append(X_logreturn1_GR[0],X_logreturn1_GR) # shape +1
X_temp_GR = (X_logreturn2_GR[:24*int(X_logreturn2_GR.shape[0]/24)]).reshape((int(X_logreturn2_GR.shape[0]/24),24))
Y_GR = np.max(X_temp_GR,axis=1)[np.arange(0,X_temp_GR.shape[0],2)]
X_GR = X_temp_GR[np.arange(0,X_temp_GR.shape[0],2),:]

X_GR=np.expand_dims(X_GR,axis=0) # shape (N,n,d) with N=1;n=?;d=24
Y_GR=np.expand_dims(Y_GR,axis=0) # shape (N,n,d) with N=1;n=?;d=24

##############################
X1_2010_JP=pd.read_csv('DAT_ASCII_JPXJPY_M1_2010.csv',sep=';',header=None)
X1_2011_JP=pd.read_csv('DAT_ASCII_JPXJPY_M1_2011.csv',sep=';',header=None)
X1_2012_JP=pd.read_csv('DAT_ASCII_JPXJPY_M1_2012.csv',sep=';',header=None)
X1_2013_JP=pd.read_csv('DAT_ASCII_JPXJPY_M1_2013.csv',sep=';',header=None)
X1_2014_JP=pd.read_csv('DAT_ASCII_JPXJPY_M1_2014.csv',sep=';',header=None)
X1_2015_JP=pd.read_csv('DAT_ASCII_JPXJPY_M1_2015.csv',sep=';',header=None)
X1_2016_JP=pd.read_csv('DAT_ASCII_JPXJPY_M1_2016.csv',sep=';',header=None)
X1_2017_JP=pd.read_csv('DAT_ASCII_JPXJPY_M1_2017.csv',sep=';',header=None)
X1_2018_JP=pd.read_csv('DAT_ASCII_JPXJPY_M1_2018.csv',sep=';',header=None)

#X1_2010_JP=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\GRXEUR\DAT_ASCII_JPXJPY_M1_2010.csv',sep=';',header=None)
#X1_2011_JP=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\GRXEUR\DAT_ASCII_JPXJPY_M1_2011.csv',sep=';',header=None)
#X1_2012_JP=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\GRXEUR\DAT_ASCII_JPXJPY_M1_2012.csv',sep=';',header=None)
#X1_2013_JP=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\GRXEUR\DAT_ASCII_JPXJPY_M1_2013.csv',sep=';',header=None)
#X1_2014_JP=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\GRXEUR\DAT_ASCII_JPXJPY_M1_2014.csv',sep=';',header=None)
#X1_2015_JP=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\GRXEUR\DAT_ASCII_JPXJPY_M1_2015.csv',sep=';',header=None)
#X1_2016_JP=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\GRXEUR\DAT_ASCII_JPXJPY_M1_2016.csv',sep=';',header=None)
#X1_2017_JP=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\GRXEUR\DAT_ASCII_JPXJPY_M1_2017.csv',sep=';',header=None)
#X1_2018_JP=pd.read_csv('miniconda3\Lib\site-packages\pyfinancialdata\data\stocks\histdata\GRXEUR\DAT_ASCII_JPXJPY_M1_2018.csv',sep=';',header=None)

X_2010_JP = ((X1_2010_JP.values)[:,4]).astype(float)
X_2011_JP = ((X1_2011_JP.values)[:,4]).astype(float)
X_2012_JP = ((X1_2012_JP.values)[:,4]).astype(float)
X_2013_JP = ((X1_2013_JP.values)[:,4]).astype(float)
X_2014_JP = ((X1_2014_JP.values)[:,4]).astype(float)
X_2015_JP = ((X1_2015_JP.values)[:,4]).astype(float)
X_2016_JP = ((X1_2016_JP.values)[:,4]).astype(float)
X_2017_JP = ((X1_2017_JP.values)[:,4]).astype(float)
X_2018_JP = ((X1_2018_JP.values)[:,4]).astype(float)
X_conc_JP=np.append(X_2010_JP,X_2011_JP)
X_conc_JP=np.append(X_conc_JP,X_2012_JP)
X_conc_JP=np.append(X_conc_JP,X_2013_JP)
X_conc_JP=np.append(X_conc_JP,X_2014_JP)
X_conc_JP=np.append(X_conc_JP,X_2015_JP)
X_conc_JP=np.append(X_conc_JP,X_2016_JP)
X_conc_JP=np.append(X_conc_JP,X_2017_JP)
X_conc_JP=np.append(X_conc_JP,X_2018_JP)

X_hour_JP= X_conc_JP[np.arange(0,X_conc_JP.shape[0]-60,60)] # conversion minutes vers hGRes
X_logreturn1_JP=np.diff(np.log(X_hour_JP)) # shape -1
X_logreturn2_JP = np.append(X_logreturn1_JP[0],X_logreturn1_JP) # shape +1
X_temp_JP = (X_logreturn2_JP[:24*int(X_logreturn2_JP.shape[0]/24)]).reshape((int(X_logreturn2_JP.shape[0]/24),24))
Y_JP = np.max(X_temp_JP,axis=1)[np.arange(0,X_temp_JP.shape[0],2)]
X_JP = X_temp_JP[np.arange(0,X_temp_JP.shape[0],2),:]

X_JP=np.expand_dims(X_JP,axis=0) # shape (N,n,d) with N=1;n=735;d=24
Y_JP=np.expand_dims(Y_JP,axis=0) # shape (N,n,d) with N=1;n=735;d=24

###############################
X1_2012_BTC=pd.read_csv('2012.csv')
X_2012_BTC = ((X1_2012_BTC.values)[:,4]).astype(float)
X1_2013_BTC=pd.read_csv('2013.csv')
X_2013_BTC = ((X1_2013_BTC.values)[:,4]).astype(float)
X_conc_BTC=np.append(X_2012_BTC,X_2013_BTC)
X1_2014_BTC=pd.read_csv('2014.csv')
X_2014_BTC = ((X1_2014_BTC.values)[:,4]).astype(float)
X_conc_BTC=np.append(X_conc_BTC,X_2014_BTC)
X1_2015_BTC=pd.read_csv('2015.csv')
X_2015_BTC = ((X1_2015_BTC.values)[:,4]).astype(float)
X_conc_BTC=np.append(X_conc_BTC,X_2015_BTC)
X1_2016_BTC=pd.read_csv('2016.csv')
X_2016_BTC = ((X1_2016_BTC.values)[:,4]).astype(float)
X_conc_BTC=np.append(X_conc_BTC,X_2016_BTC)
X1_2017_BTC=pd.read_csv('2017.csv')
X_2017_BTC = ((X1_2017_BTC.values)[:,4]).astype(float)
X_conc_BTC=np.append(X_conc_BTC,X_2017_BTC)
X1_2018_BTC=pd.read_csv('2018.csv')
X_2018_BTC = ((X1_2018_BTC.values)[:,4]).astype(float)
X_conc_BTC=np.append(X_conc_BTC,X_2018_BTC)

#plt.plot(X_conc) # cours du Bitcoin 
X_hour_BTC= X_conc_BTC[np.arange(0,X_conc_BTC.shape[0]-60,60)] # conversion minutes vers heures
X_logreturn1_BTC=np.diff(np.log(X_hour_BTC)) # shape -1
X_logreturn2_BTC = np.append(X_logreturn1_BTC[0],X_logreturn1_BTC) # shape +1
X_temp_BTC = (X_logreturn2_BTC[:24*int(X_logreturn2_BTC.shape[0]/24)]).reshape((int(X_logreturn2_BTC.shape[0]/24),24))
Y_BTC = np.max(X_temp_BTC,axis=1)[np.arange(0,X_temp_BTC.shape[0],2)]
X_BTC = X_temp_BTC[np.arange(0,X_temp_BTC.shape[0],2),:]
X_BTC=np.expand_dims(X_BTC,axis=0) # shape (1,735,24)
Y_BTC=np.expand_dims(Y_BTC,axis=0) # shape (1,735)


# Remove the two largest values in Y and the corresponding values in X
index_to_remove1_BTC = np.argmax(Y_BTC,axis=1)
Y_BTC_new1 = np.expand_dims(np.delete(Y_BTC[0,:],index_to_remove1_BTC),axis=0)
X_BTC_new1=np.delete(X_BTC,index_to_remove1_BTC,axis=1)
index_to_remove2_BTC=np.argmax(Y_BTC_new1,axis=1)
Y_BTC_reduced=np.expand_dims(np.delete(Y_BTC_new1,index_to_remove2_BTC),axis=0)
X_BTC_reduced=np.delete(X_BTC_new1,index_to_remove2_BTC,axis=1)


##################### Hill estimator
#gamma=1/3
#Y_sim = Pareto_quantile_function(npr.uniform(0,1,size=(1,500)),gamma,2)

G_SP=get_hill_estimator(np.sort(Y_SP[0,:])[::-1])
G_BTC=get_hill_estimator(np.sort(Y_BTC[0,:])[::-1])
G_BTC_reduced=get_hill_estimator(np.sort(Y_BTC_reduced[0,:])[::-1])
G_EUR=get_hill_estimator(np.sort(Y_EUR[0,:])[::-1])
G_GR=get_hill_estimator(np.sort(Y_JP[0,:])[::-1])
G_JP=get_hill_estimator(np.sort(Y_GR[0,:])[::-1])

#G_sim=get_hill_estimator(np.sort(Y_sim[0,:])[::-1])

sh= [Y_BTC.shape[1],Y_SP.shape[1],Y_EUR.shape[1],Y_BTC_reduced.shape[1],Y_JP.shape[1],Y_GR.shape[1]]

index_min = min(sh)-1

plt.plot(G_SP[:index_min],label='SP500')
plt.plot(G_EUR[:index_min],label='EUR')
plt.plot(G_GR[:index_min],label='GR')
plt.plot(G_JP[:index_min],label='JP')
plt.plot(G_BTC[:index_min],label='BTC')
plt.plot(G_BTC_reduced[:index_min],label='BTC (reduced)')

#plt.plot(G_sim[:index_min],label='Pareto')

#plt.xlim(0, 300)  # setting limits for x-axis from 0 to 6
#plt.ylim(0, 5) # setting limits for y-axis from 0 to 12

plt.legend()
plt.savefig("tail_index_financial_data.pdf") 
plt.show()

####################### Exponential Quantile-Quantile Plot
k=100
QQ=Exponential_QQ_Plot_1D(Y_SP,k)
x=QQ[:,0]
y=QQ[:,1]
res=linregress(QQ[:,0],QQ[:,1])
plt.plot(QQ[:,0], QQ[:,1], 'o')
plt.plot(QQ[:,0], res.intercept + res.slope*QQ[:,0], 'r')
plt.savefig('QQ_SP500_100.pdf')  
plt.show()

k=100
QQ=Exponential_QQ_Plot_1D(Y_EUR,k)
x=QQ[:,0]
y=QQ[:,1]
res=linregress(QQ[:,0],QQ[:,1])
plt.plot(QQ[:,0], QQ[:,1], 'o')
plt.plot(QQ[:,0], res.intercept + res.slope*QQ[:,0], 'r')
plt.savefig('QQ_EUR_100.pdf')  
plt.show()

k=100
QQ=Exponential_QQ_Plot_1D(Y_GR,k)
x=QQ[:,0]
y=QQ[:,1]
res=linregress(QQ[:,0],QQ[:,1])
plt.plot(QQ[:,0], QQ[:,1], 'o')
plt.plot(QQ[:,0], res.intercept + res.slope*QQ[:,0], 'r')
plt.savefig('QQ_GR_100.pdf')  
plt.show()

k=100
QQ=Exponential_QQ_Plot_1D(Y_JP,k)
x=QQ[:,0]
y=QQ[:,1]
res=linregress(QQ[:,0],QQ[:,1])
plt.plot(QQ[:,0], QQ[:,1], 'o')
plt.plot(QQ[:,0], res.intercept + res.slope*QQ[:,0], 'r')
plt.savefig('QQ_JP_100.pdf')  
plt.show()

k=100
QQ=Exponential_QQ_Plot_1D(Y_BTC,k)
x=QQ[:,0]
y=QQ[:,1]
res=linregress(QQ[:,0],QQ[:,1])
plt.plot(QQ[:,0], QQ[:,1], 'o')
plt.plot(QQ[:,0], res.intercept + res.slope*QQ[:,0], 'r')
plt.savefig('QQ_BTC_100.pdf')  
plt.show()

k=100
QQ=Exponential_QQ_Plot_1D(Y_BTC_reduced,k)
x=QQ[:,0]
y=QQ[:,1]
res=linregress(QQ[:,0],QQ[:,1])
plt.plot(QQ[:,0], QQ[:,1], 'o')
plt.plot(QQ[:,0], res.intercept + res.slope*QQ[:,0], 'r')
plt.savefig('QQ_BTC_reduced_100.pdf')  
plt.show()


############################### Correlation and Scatterplot

start=14
tau=-2

m=int(X_SP.shape[1]/10) 
y_matrix_SP = bitcoin_threshold(X_SP,Y_SP,tau,m,start)
C0_SP = bitcoin_concomittant_corr(X_SP,Y_SP,tau,100)
E0_SP=fepls(X_SP,Y_SP,y_matrix_SP,tau)
F0_SP=hatbeta_dot_X(X_SP,E0_SP)
plt.plot(C0_SP)
plt.savefig('Corr_SP500_5_tau_-2.pdf')  
plt.show()
plt.scatter(F0_SP[0,:], Y_SP[0,:], color='blue', marker='o')
highest_indices_SP = np.argsort(Y_SP)[0,-bitcoin_threshold_index(X_SP,Y_SP,tau,m,start):]
plt.scatter(F0_SP[0,highest_indices_SP], Y_SP[0,highest_indices_SP], color='red')
plt.savefig('Scatter_SP500_5_tau_-2.pdf')  
plt.show()

m=int(X_EUR.shape[1]/10) 
y_matrix_EUR = bitcoin_threshold(X_EUR,Y_EUR,tau,m,start)
C0_EUR = bitcoin_concomittant_corr(X_EUR,Y_EUR,tau,100)
E0_EUR=fepls(X_EUR,Y_EUR,y_matrix_EUR,tau)
F0_EUR=hatbeta_dot_X(X_EUR,E0_EUR)
plt.plot(C0_EUR)
plt.savefig('Corr_EUR_5_tau_-2.pdf')  
plt.show()
plt.scatter(F0_EUR[0,:], Y_EUR[0,:], color='blue', marker='o')
highest_indices_EUR = np.argsort(Y_EUR)[0,-bitcoin_threshold_index(X_EUR,Y_EUR,tau,m,start):]
plt.scatter(F0_EUR[0,highest_indices_EUR], Y_EUR[0,highest_indices_EUR], color='red')
plt.savefig('Scatter_EUR_5_tau_-2.pdf')  
plt.show()

m=int(X_GR.shape[1]/10) 
y_matrix_GR = bitcoin_threshold(X_GR,Y_GR,tau,m,start)
C0_GR = bitcoin_concomittant_corr(X_GR,Y_GR,tau,100)
E0_GR=fepls(X_GR,Y_GR,y_matrix_GR,tau)
F0_GR=hatbeta_dot_X(X_GR,E0_GR)
plt.plot(C0_GR)
plt.savefig('Corr_GR_5_tau_-2.pdf')  
plt.show()
plt.scatter(F0_GR[0,:], Y_GR[0,:], color='blue', marker='o')
highest_indices_GR = np.argsort(Y_GR)[0,-bitcoin_threshold_index(X_GR,Y_GR,tau,m,start):]
plt.scatter(F0_GR[0,highest_indices_GR], Y_GR[0,highest_indices_GR], color='red')
plt.savefig('Scatter_GR_5_tau_-2.pdf')  
plt.show()

m=int(X_JP.shape[1]/10) 
y_matrix_JP = bitcoin_threshold(X_JP,Y_JP,tau,m,start)
C0_JP = bitcoin_concomittant_corr(X_JP,Y_JP,tau,100)
E0_JP=fepls(X_JP,Y_JP,y_matrix_JP,tau)
F0_JP=hatbeta_dot_X(X_JP,E0_JP)
plt.plot(C0_JP)
plt.savefig('Corr_JP_5_tau_-2.pdf')  
plt.show()
plt.scatter(F0_JP[0,:], Y_JP[0,:], color='blue', marker='o')
highest_indices_JP = np.argsort(Y_JP)[0,-bitcoin_threshold_index(X_JP,Y_JP,tau,m,start):]
plt.scatter(F0_JP[0,highest_indices_JP], Y_JP[0,highest_indices_JP], color='red')
plt.savefig('Scatter_JP_5_tau_-2.pdf')  
plt.show()

m=int(X_BTC.shape[1]/10) 
y_matrix_BTC = bitcoin_threshold(X_BTC,Y_BTC,tau,m,start)
C0_BTC = bitcoin_concomittant_corr(X_BTC,Y_BTC,tau,100)
E0_BTC=fepls(X_BTC,Y_BTC,y_matrix_BTC,tau)
F0_BTC=hatbeta_dot_X(X_BTC,E0_BTC)
plt.plot(C0_BTC)
plt.savefig('Corr_BTC_9_tau_-2.pdf')  
plt.show()
plt.scatter(F0_BTC[0,:], Y_BTC[0,:], color='blue', marker='o')
highest_indices_BTC = np.argsort(Y_BTC)[0,-bitcoin_threshold_index(X_BTC,Y_BTC,tau,m,start):]
plt.scatter(F0_BTC[0,highest_indices_BTC], Y_BTC[0,highest_indices_BTC], color='red')
plt.savefig('Scatter_BTC_9_tau_-2.pdf')  
plt.show()

m=int(X_BTC_reduced.shape[1]/10) 
y_matrix_BTC_reduced = bitcoin_threshold(X_BTC_reduced,Y_BTC_reduced,tau,m,start)
C0_BTC_reduced = bitcoin_concomittant_corr(X_BTC_reduced,Y_BTC_reduced,tau,100)
E0_BTC_reduced=fepls(X_BTC_reduced,Y_BTC_reduced,y_matrix_BTC_reduced,tau)
F0_BTC_reduced=hatbeta_dot_X(X_BTC_reduced,E0_BTC_reduced)
plt.plot(C0_BTC_reduced)
plt.savefig('Corr_BTC_reduced_9_tau_-2.pdf')  
plt.show()
plt.scatter(F0_BTC_reduced[0,:], Y_BTC_reduced[0,:], color='blue', marker='o')
highest_indices_BTC_reduced = np.argsort(Y_BTC_reduced)[0,-bitcoin_threshold_index(X_BTC_reduced,Y_BTC_reduced,tau,m,start):]
plt.scatter(F0_BTC_reduced[0,highest_indices_BTC_reduced], Y_BTC_reduced[0,highest_indices_BTC_reduced], color='red')
plt.savefig('Scatter_BTC_9_reduced_tau_-2.pdf')  
plt.show()

########################################################## Correlation for different tau

C0_SP1 = bitcoin_concomittant_corr(X_SP,Y_SP,-2,100)
C0_SP2 = bitcoin_concomittant_corr(X_SP,Y_SP,-1,100)
C0_SP3 = bitcoin_concomittant_corr(X_SP,Y_SP,0,100)
C0_SP4 = bitcoin_concomittant_corr(X_SP,Y_SP,1,100)
C0_SP5 = bitcoin_concomittant_corr(X_SP,Y_SP,2,100)
plt.plot(C0_SP1,label='tau=-2')
plt.plot(C0_SP2,label='tau=-1')
plt.plot(C0_SP3,label='tau=0')
plt.plot(C0_SP4,label='tau=1')
plt.plot(C0_SP5,label='tau=2')
#plt.xlim(0, 300)  # setting limits for x-axis from 0 to 6
#plt.ylim(0, 5) # setting limits for y-axis from 0 to 12
plt.legend()
plt.savefig('Corr_SP500.pdf')  
plt.show()

C0_EUR1 = bitcoin_concomittant_corr(X_EUR,Y_EUR,-2,100)
C0_EUR2 = bitcoin_concomittant_corr(X_EUR,Y_EUR,-1,100)
C0_EUR3 = bitcoin_concomittant_corr(X_EUR,Y_EUR,0,100)
C0_EUR4 = bitcoin_concomittant_corr(X_EUR,Y_EUR,1,100)
C0_EUR5 = bitcoin_concomittant_corr(X_EUR,Y_EUR,2,100)
plt.plot(C0_EUR1,label='tau=-2')
plt.plot(C0_EUR2,label='tau=-1')
plt.plot(C0_EUR3,label='tau=0')
plt.plot(C0_EUR4,label='tau=1')
plt.plot(C0_EUR5,label='tau=2')
#plt.xlim(0, 300)  # setting limits for x-axis from 0 to 6
#plt.ylim(0, 5) # setting limits for y-axis from 0 to 12
plt.legend()
plt.savefig('Corr_EUR.pdf')  
plt.show()

C0_GR1 = bitcoin_concomittant_corr(X_GR,Y_GR,-2,100)
C0_GR2 = bitcoin_concomittant_corr(X_GR,Y_GR,-1,100)
C0_GR3 = bitcoin_concomittant_corr(X_GR,Y_GR,0,100)
C0_GR4 = bitcoin_concomittant_corr(X_GR,Y_GR,1,100)
C0_GR5 = bitcoin_concomittant_corr(X_GR,Y_GR,2,100)
plt.plot(C0_GR1,label='tau=-2')
plt.plot(C0_GR2,label='tau=-1')
plt.plot(C0_GR3,label='tau=0')
plt.plot(C0_GR4,label='tau=1')
plt.plot(C0_GR5,label='tau=2')
#plt.xlim(0, 300)  # setting limits for x-axis from 0 to 6
#plt.ylim(0, 5) # setting limits for y-axis from 0 to 12
plt.legend()
plt.savefig('Corr_GR.pdf')  
plt.show()

C0_JP1 = bitcoin_concomittant_corr(X_JP,Y_JP,-2,100)
C0_JP2 = bitcoin_concomittant_corr(X_JP,Y_JP,-1,100)
C0_JP3 = bitcoin_concomittant_corr(X_JP,Y_JP,0,100)
C0_JP4 = bitcoin_concomittant_corr(X_JP,Y_JP,1,100)
C0_JP5 = bitcoin_concomittant_corr(X_JP,Y_JP,2,100)
plt.plot(C0_JP1,label='tau=-2')
plt.plot(C0_JP2,label='tau=-1')
plt.plot(C0_JP3,label='tau=0')
plt.plot(C0_JP4,label='tau=1')
plt.plot(C0_JP5,label='tau=2')
#plt.xlim(0, 300)  # setting limits for x-axis from 0 to 6
#plt.ylim(0, 5) # setting limits for y-axis from 0 to 12
plt.legend()
plt.savefig('Corr_JP.pdf')  
plt.show()

C0_BTC1 = bitcoin_concomittant_corr(X_BTC,Y_BTC,-2,100)
C0_BTC2 = bitcoin_concomittant_corr(X_BTC,Y_BTC,-1,100)
C0_BTC3 = bitcoin_concomittant_corr(X_BTC,Y_BTC,0,100)
C0_BTC4 = bitcoin_concomittant_corr(X_BTC,Y_BTC,1,100)
C0_BTC5 = bitcoin_concomittant_corr(X_BTC,Y_BTC,2,100)
plt.plot(C0_BTC1,label='tau=-2')
plt.plot(C0_BTC2,label='tau=-1')
plt.plot(C0_BTC3,label='tau=0')
plt.plot(C0_BTC4,label='tau=1')
plt.plot(C0_BTC5,label='tau=2')
#plt.xlim(0, 300)  # setting limits for x-axis from 0 to 6
#plt.ylim(0, 5) # setting limits for y-axis from 0 to 12
plt.legend()
plt.savefig('Corr_BTC.pdf')  
plt.show()

C0_BTC_reduced1 = bitcoin_concomittant_corr(X_BTC_reduced,Y_BTC_reduced,-2,100)
C0_BTC_reduced2 = bitcoin_concomittant_corr(X_BTC_reduced,Y_BTC_reduced,-1,100)
C0_BTC_reduced3 = bitcoin_concomittant_corr(X_BTC_reduced,Y_BTC_reduced,0,100)
C0_BTC_reduced4 = bitcoin_concomittant_corr(X_BTC_reduced,Y_BTC_reduced,1,100)
C0_BTC_reduced5 = bitcoin_concomittant_corr(X_BTC_reduced,Y_BTC_reduced,2,100)
plt.plot(C0_BTC_reduced1,label='tau=-2')
#plt.plot(C0_BTC_reduced2,label='tau=-1')
plt.plot(C0_BTC_reduced3,label='tau=0')
#plt.plot(C0_BTC_reduced4,label='tau=1')
plt.plot(C0_BTC_reduced5,label='tau=2')
#plt.xlim(14, 100)  # setting limits for x-axis from 0 to 6
#plt.ylim(0, 5) # setting limits for y-axis from 0 to 12
plt.legend()
plt.savefig('Corr_BTC_reduced.pdf')  
plt.show()

plt.plot(np.abs(C0_BTC_reduced1),label='tau=-2')
#plt.plot(C0_BTC_reduced2,label='tau=-1')
plt.plot(np.abs(C0_BTC_reduced3),label='tau=0')
#plt.plot(C0_BTC_reduced4,label='tau=1')
plt.plot(np.abs(C0_BTC_reduced5),label='tau=2')
#plt.xlim(14, 100)  # setting limits for x-axis from 0 to 6
#plt.ylim(0, 5) # setting limits for y-axis from 0 to 12
plt.legend()
plt.savefig('Corr_absolute_BTC_reduced.pdf')  
plt.show()

############################## Bitcoin (Antoine version) application (Correlation, Scatterplot)

X_df = pd.read_csv('X.csv') # Antoine data for BTC, i.e., without 2015 year
Y_df = pd.read_csv('Y.csv') # Antoine data for BTC, i.e., without 2015 year

X_Antoine_BTC=np.expand_dims(X_df.values,axis=0) # shape (N,n,d) with N=1;n=917;d=24
Y_Antoine_BTC=np.transpose(Y_df.values) # shape (N,n) with N=1;n=917

# Remove the two largest values in Y and the corresponding values in X
index_to_remove1 = np.argmax(Y_Antoine_BTC,axis=1)
Y_new1 = np.expand_dims(np.delete(Y_Antoine_BTC[0,:],index_to_remove1),axis=0)
X_new1=np.delete(X_Antoine_BTC,index_to_remove1,axis=1)
index_to_remove2=np.argmax(Y_new1,axis=1)
Y_Antoine_BTC_reduced=np.expand_dims(np.delete(Y_new1,index_to_remove2),axis=0)
X_Antoine_BTC_reduced=np.delete(X_new1,index_to_remove2,axis=1)
index_to_remove_zero = np.where(Y_Antoine_BTC_reduced==0)
Y_Antoine_BTC_reduced_zero = np.expand_dims(np.delete(Y_Antoine_BTC_reduced[0,:],index_to_remove_zero),axis=0)
X_Antoine_BTC_reduced_zero=np.delete(X_Antoine_BTC_reduced,index_to_remove_zero,axis=1)

Y_new=Y_Antoine_BTC_reduced_zero
X_new=X_Antoine_BTC_reduced_zero

tau=-2
tau2=-1
tau3=0
tau4=1
tau5=2

start = 14

m=101

y_matrix_new= bitcoin_threshold(X_new,Y_new,tau,101,start)
C0_new = bitcoin_concomittant_corr(X_new,Y_new,tau,50)
E0_new=fepls(X_new,Y_new,y_matrix_new,tau)
F0_new=hatbeta_dot_X(X_new,E0_new)

y_matrix_new2= bitcoin_threshold(X_new,Y_new,tau2,101,start)
C0_new2 = bitcoin_concomittant_corr(X_new,Y_new,tau2,50)

y_matrix_new3= bitcoin_threshold(X_new,Y_new,tau3,101,start)
C0_new3 = bitcoin_concomittant_corr(X_new,Y_new,tau3,50)
y_matrix_new4= bitcoin_threshold(X_new,Y_new,tau4,101,start)
C0_new4 = bitcoin_concomittant_corr(X_new,Y_new,tau4,50)
y_matrix_new5= bitcoin_threshold(X_new,Y_new,tau5,101,start)
C0_new5 = bitcoin_concomittant_corr(X_new,Y_new,tau5,50)

plt.plot(C0_new,label='tau = -2')
plt.plot(C0_new2,label='tau = -1')
plt.plot(C0_new3,label='tau = 0')
plt.plot(C0_new4,label='tau = 1')
plt.plot(C0_new5,label='tau = 2')
plt.legend()
#plt.savefig('Corr_BTC_Antoine_reduced_no_zero_tau_-1.pdf')  
plt.show()

plt.scatter(F0_new[0,:], Y_new[0,:], color='blue', marker='o')
index=bitcoin_threshold_index(X_new,Y_new,tau,m,start)
highest_indices = np.argsort(Y_new)[0,-index:]
plt.scatter(F0_new[0,highest_indices], Y_new[0,highest_indices], color='red')
#plt.savefig('Scatter_Antoine_BTC_reduced_no_zero_tau_-1.pdf')  
plt.show()

# %%
#### BTC_reduced
X1_2012_BTC=pd.read_csv('2012.csv')
X_2012_BTC = ((X1_2012_BTC.values)[:,4]).astype(float)
X1_2013_BTC=pd.read_csv('2013.csv')
X_2013_BTC = ((X1_2013_BTC.values)[:,4]).astype(float)
X_conc_BTC=np.append(X_2012_BTC,X_2013_BTC)
X1_2014_BTC=pd.read_csv('2014.csv')
X_2014_BTC = ((X1_2014_BTC.values)[:,4]).astype(float)
X_conc_BTC=np.append(X_conc_BTC,X_2014_BTC)
X1_2015_BTC=pd.read_csv('2015.csv')
X_2015_BTC = ((X1_2015_BTC.values)[:,4]).astype(float)
X_conc_BTC=np.append(X_conc_BTC,X_2015_BTC)
X1_2016_BTC=pd.read_csv('2016.csv')
X_2016_BTC = ((X1_2016_BTC.values)[:,4]).astype(float)
X_conc_BTC=np.append(X_conc_BTC,X_2016_BTC)
X1_2017_BTC=pd.read_csv('2017.csv')
X_2017_BTC = ((X1_2017_BTC.values)[:,4]).astype(float)
X_conc_BTC=np.append(X_conc_BTC,X_2017_BTC)
X1_2018_BTC=pd.read_csv('2018.csv')
X_2018_BTC = ((X1_2018_BTC.values)[:,4]).astype(float)
X_conc_BTC=np.append(X_conc_BTC,X_2018_BTC)

#plt.plot(X_conc) # cours du Bitcoin 
X_hour_BTC= X_conc_BTC[np.arange(0,X_conc_BTC.shape[0]-60,60)] # conversion minutes vers heures
X_logreturn1_BTC=np.diff(np.log(X_hour_BTC)) # shape -1
X_logreturn2_BTC = np.append(X_logreturn1_BTC[0],X_logreturn1_BTC) # shape +1
X_temp_BTC = (X_logreturn2_BTC[:24*int(X_logreturn2_BTC.shape[0]/24)]).reshape((int(X_logreturn2_BTC.shape[0]/24),24))
Y_BTC = np.max(X_temp_BTC,axis=1)[np.arange(0,X_temp_BTC.shape[0],2)]
X_BTC = X_temp_BTC[np.arange(0,X_temp_BTC.shape[0],2),:]
X_BTC=np.expand_dims(X_BTC,axis=0) # shape (1,735,24)
Y_BTC=np.expand_dims(Y_BTC,axis=0) # shape (1,735)


# Remove the two largest values in Y and the corresponding values in X
index_to_remove1_BTC = np.argmax(Y_BTC,axis=1)
Y_BTC_new1 = np.expand_dims(np.delete(Y_BTC[0,:],index_to_remove1_BTC),axis=0)
X_BTC_new1=np.delete(X_BTC,index_to_remove1_BTC,axis=1)
index_to_remove2_BTC=np.argmax(Y_BTC_new1,axis=1)
Y_BTC_reduced=np.expand_dims(np.delete(Y_BTC_new1,index_to_remove2_BTC),axis=0)
X_BTC_reduced=np.delete(X_BTC_new1,index_to_remove2_BTC,axis=1)

##################### Hill estimator

G_BTC_reduced=get_hill_estimator(np.sort(Y_BTC_reduced[0,:])[::-1])
plt.plot(G_BTC_reduced[:500])
plt.savefig("Hill_BTC_reduced.pdf") 
plt.show()

####################### Exponential Quantile-Quantile Plot
#k=100
#QQ=Exponential_QQ_Plot_1D(Y_BTC_reduced,k)
#x=QQ[:,0]
#y=QQ[:,1]
#res=linregress(QQ[:,0],QQ[:,1])
#plt.plot(QQ[:,0], QQ[:,1], 'o')
#plt.plot(QQ[:,0], res.intercept + res.slope*QQ[:,0], 'r')
#plt.savefig('QQ_BTC_reduced_100.pdf')  
#plt.show()

############################### Correlation and Scatterplot

start=14
tau=-2

m=101
y_matrix_BTC_reduced = bitcoin_threshold(X_BTC_reduced,Y_BTC_reduced,tau,m,start)
C0_BTC_reduced = bitcoin_concomittant_corr(X_BTC_reduced,Y_BTC_reduced,tau,100)
E0_BTC_reduced=fepls(X_BTC_reduced,Y_BTC_reduced,y_matrix_BTC_reduced,tau)
F0_BTC_reduced=hatbeta_dot_X(X_BTC_reduced,E0_BTC_reduced)
#plt.plot(C0_BTC_reduced)
#plt.savefig('Corr_BTC_reduced_15_tau_-2.pdf')  
#plt.show()
plt.scatter(F0_BTC_reduced[0,:], Y_BTC_reduced[0,:], color='blue', marker='o')
highest_indices_BTC_reduced = np.argsort(Y_BTC_reduced)[0,-bitcoin_threshold_index(X_BTC_reduced,Y_BTC_reduced,tau,m,start):]
plt.scatter(F0_BTC_reduced[0,highest_indices_BTC_reduced], Y_BTC_reduced[0,highest_indices_BTC_reduced], color='red')
#plt.savefig('Scatter_BTC_reduced_15_tau_-2.pdf')  
plt.show()

########################################################## Correlation for different tau

C0_BTC_reduced1 = bitcoin_concomittant_corr(X_BTC_reduced,Y_BTC_reduced,-2,100)
C0_BTC_reduced3 = bitcoin_concomittant_corr(X_BTC_reduced,Y_BTC_reduced,0,100)
C0_BTC_reduced5 = bitcoin_concomittant_corr(X_BTC_reduced,Y_BTC_reduced,2,100)
plt.plot(C0_BTC_reduced1,label='tau=-2')
plt.plot(C0_BTC_reduced3,label='tau=0')
plt.plot(C0_BTC_reduced5,label='tau=2')
plt.xlim(14, 100)  # setting limits for x-axis from 0 to 6
plt.ylim(-0.5, 0.6) # setting limits for y-axis from 0 to 12
plt.legend()
plt.savefig('Corr_BTC_reduced.pdf')  
plt.show()

plt.plot(np.abs(C0_BTC_reduced1),label='tau=-2')
#plt.plot(C0_BTC_reduced2,label='tau=-1')
plt.plot(np.abs(C0_BTC_reduced3),label='tau=0')
#plt.plot(C0_BTC_reduced4,label='tau=1')
plt.plot(np.abs(C0_BTC_reduced5),label='tau=2')
plt.xlim(14, 100)  # setting limits for x-axis from 0 to 6
plt.ylim(-0.05, 0.5) # setting limits for y-axis from 0 to 12
plt.legend()
plt.savefig('Corr_absolute_BTC_reduced.pdf')  
plt.show()

# %%
def hist_weight_extreme_2D(X_2D,Y,Y_sort_index, x_func,x,tau,m,start): # X_2D.shape = (n,d); x in \R; x_func \in H ie of shape (d,)
    d=x_func.shape[0] # Y of shape (N,n) and Y_sort_index = np.argsort(Y,axis=1)
    thresholdd = threshold(np.expand_dims(X_2D,axis=0),Y,Y_sort_index,tau,m,start)
    index_to_remove = np.where(Y<=thresholdd)
    X_extreme_2D=np.delete(X_2D,index_to_remove,axis=0)
    aux = (X_extreme_2D-x*x_func*np.ones(d))**2 # shape = (n2,d)
    out=np.zeros((X_extreme_2D.shape[0],2))
    out[:,0] = np.sqrt((1/d)*np.sum(aux,axis=1)) # shape = (n2,)
    out[:,1]= np.dot(X_extreme_2D,x_func)/d-x
    return out ### shape = (n2,)

def hist_weight_2D(X_2D,Y,Y_sort_index, x_func,x,tau,m,start): # X_2D.shape = (n,d); x in \R; x_func \in H ie of shape (d,)
    d=x_func.shape[0] # Y of shape (N,n) and Y_sort_index = np.argsort(Y,axis=1)
    aux = (X_2D-x*x_func*np.ones(d))**2 
    out=np.zeros((X_2D.shape[0],2))
    out[:,0] = np.sqrt((1/d)*np.sum(aux,axis=1)) 
    out[:,1]= np.dot(X_2D,x_func)/d-x
    return out ### shape = (n,)

@numba.njit(parallel=True, fastmath=False)
def hist_weight_extreme_2D_total(X_extreme_2D,x_func,a,b,m): 
    n2=X_extreme_2D.shape[0]
    d=X_extreme_2D.shape[1]
    x_grid = np.linspace(a,b,m)
    out=np.zeros((n2,m,2))
    for p in numba.prange(m):
        aux = (X_extreme_2D-x_grid[p]*x_func*np.ones(d))**2 # shape = (n2,d)
        out[:,p,0] = np.sqrt((1/d)*np.sum(aux,axis=1)) # shape = (n2,)
        out[:,p,1]= np.dot(X_extreme_2D,x_func)/d-x_grid[p]
    return out ### shape = (n2,)

@numba.njit(parallel=True, fastmath=False)
def hist_weight_2D_total(X_2D,x_func,a,b,m): 
    n=X_2D.shape[0]
    d=X_2D.shape[1]
    x_grid = np.linspace(a,b,m)
    out=np.zeros((n,m,2))
    for p in numba.prange(m):
        aux = (X_2D-x_grid[p]*x_func*np.ones(d))**2 # shape = (n,d)
        out[:,p,0] = np.sqrt((1/d)*np.sum(aux,axis=1)) # shape = (n,)
        out[:,p,1]= np.dot(X_2D,x_func)/d-x_grid[p]
    return out ### shape = (n,)

x=0
start = 14
m=X_BTC_reduced.shape[1]
a=-0.01
b=0.03
tau=-2
alpha1=0.95
alpha2=0.98
kernel=2 # Gaussian kernel
J=9
s1=500
s2=500

#####################################
X_2D = X_BTC_reduced[0,:,:]
Y_sort_index = np.argsort(Y_BTC_reduced,axis=1)
x_func = E0_BTC_reduced[0,:]
#############################
H_extreme=hist_weight_extreme_2D(X_2D,Y_BTC_reduced,Y_sort_index,x_func,x,tau,m,start)
thresholdd = threshold(X_BTC_reduced,Y_BTC_reduced,Y_sort_index,tau,m,start)
index_to_remove = np.where(Y_BTC_reduced<=thresholdd)
X_extreme_2D=np.delete(X_2D,index_to_remove,axis=0)
H_total_extreme=hist_weight_extreme_2D_total(X_extreme_2D,x_func,a,b,m)
#############################
plt.hist(H_extreme[:,0],bins=100)
plt.title('Extreme univariate')
plt.show()
plt.hist(H_extreme[:,1],bins=100)
plt.title('Extreme functional')
plt.show()
#############################
H_bulk=hist_weight_2D(X_2D,Y_BTC_reduced,Y_sort_index,x_func,x,tau,m,start)
H_total_bulk=hist_weight_2D_total(X_2D,x_func,a,b,m)
#############################
plt.hist(H_bulk[:,0],bins=100)
plt.title('Bulk univariate')
plt.show()
plt.hist(H_bulk[:,1],bins=100)
plt.title('Bulk functional')
plt.show()

#######################################
N=X_BTC_reduced.shape[0]
n=X_BTC_reduced.shape[1]
d=X_BTC_reduced.shape[2]

h_vector_extreme = (np.max(H_total_extreme[:,:,0],axis=0)-np.min(H_total_extreme[:,:,0],axis=0))/s1
h_func_vector_extreme = (np.max(H_total_extreme[:,:,1],axis=0)-np.min(H_total_extreme[:,:,1],axis=0))/s2
h_extreme=(np.max(H_extreme[:,0],axis=0)-np.min(H_extreme[:,0],axis=0))/s1
h_func_extreme=(np.max(H_extreme[:,1],axis=0)-np.min(H_extreme[:,1],axis=0))/s2
h_func_2D_extreme=np.transpose(np.outer(h_func_extreme*np.ones(n),np.ones(N))) # of shape (N,n) where A.shape = (n,); e.g., A=h_func*np.ones(n)

h_vector_bulk = (np.max(H_total_bulk[:,:,0],axis=0)-np.min(H_total_bulk[:,:,0],axis=0))/s1
h_func_vector_bulk = (np.max(H_total_bulk[:,:,1],axis=0)-np.min(H_total_bulk[:,:,1],axis=0))/s2
h_bulk=(np.max(H_bulk[:,0],axis=0)-np.min(H_bulk[:,0],axis=0))/s1
h_func_bulk=(np.max(H_bulk[:,1],axis=0)-np.min(H_bulk[:,1],axis=0))/s2
h_func_2D_bulk=np.transpose(np.outer(h_func_bulk*np.ones(n),np.ones(N))) # of shape (N,n) where A.shape = (n,); e.g., A=h_func*np.ones(n)

# Y|(X,dimred1)=(x*x_func,dimred1) (type 1) vs Y|(X,dimred2) = x (type 2) vs Y|X = x*x_func (type functional)
#PP1_extreme=plot_quantile_dimred_vs_func_2D(X_BTC_reduced,Y_BTC_reduced,E0_BTC_reduced[0,:],E0_BTC_reduced[0,:],E0_BTC_reduced[0,:],alpha1,a,b,m,h_extreme,h_func_extreme,kernel) 
PP11_extreme=plot_quantile_dimred_vs_func_2D_total(X_BTC_reduced,Y_BTC_reduced,E0_BTC_reduced[0,:],E0_BTC_reduced[0,:],E0_BTC_reduced[0,:],alpha1,a,b,m,h_vector_extreme,h_func_vector_extreme,kernel) 
PP112_extreme=plot_quantile_dimred_vs_func_2D_total(X_BTC_reduced,Y_BTC_reduced,E0_BTC_reduced[0,:],E0_BTC_reduced[0,:],E0_BTC_reduced[0,:],alpha2,a,b,m,h_vector_extreme,h_func_vector_extreme,kernel) 

#PP2_extreme=plot_quantile_dimred_vs_func_2D(X_BTC_reduced,Y_BTC_reduced,beta_func2(d),beta_func2(d),beta_func2(d),alpha1,a,b,m,h_extreme,h_func_extreme,kernel) 
#PP22_extreme=plot_quantile_dimred_vs_func_2D_total(X_BTC_reduced,Y_BTC_reduced,beta_func2(d),beta_func2(d),beta_func2(d),alpha1,a,b,m,h_vector_extreme,h_func_vector_extreme,kernel) 

#PP1_bulk=plot_quantile_dimred_vs_func_2D(X_BTC_reduced,Y_BTC_reduced,E0_BTC_reduced[0,:],E0_BTC_reduced[0,:],E0_BTC_reduced[0,:],alpha1,a,b,m,h_bulk,h_func_bulk,kernel) 
PP11_bulk=plot_quantile_dimred_vs_func_2D_total(X_BTC_reduced,Y_BTC_reduced,E0_BTC_reduced[0,:],E0_BTC_reduced[0,:],E0_BTC_reduced[0,:],alpha1,a,b,m,h_vector_bulk,h_func_vector_bulk,kernel) 
PP112_bulk=plot_quantile_dimred_vs_func_2D_total(X_BTC_reduced,Y_BTC_reduced,E0_BTC_reduced[0,:],E0_BTC_reduced[0,:],E0_BTC_reduced[0,:],alpha2,a,b,m,h_vector_bulk,h_func_vector_bulk,kernel) 
#PP2_bulk=plot_quantile_dimred_vs_func_2D(X_BTC_reduced,Y_BTC_reduced,beta_func2(d),beta_func2(d),beta_func2(d),alpha1,a,b,m,h_bulk,h_func_bulk,kernel) 
#PP22_bulk=plot_quantile_dimred_vs_func_2D_total(X_BTC_reduced,Y_BTC_reduced,beta_func2(d),beta_func2(d),beta_func2(d),alpha1,a,b,m,h_vector_bulk,h_func_vector_bulk,kernel) 

plt.plot(PP11_extreme[:,0])
plt.plot(PP11_extreme[:,1])
plt.plot(PP11_extreme[:,2])
plt.title('Conditional quantiles; h_extreme')
plt.show()
plt.plot(PP11_bulk[:,0])
plt.plot(PP11_bulk[:,1])
plt.plot(PP11_bulk[:,2])
plt.title('Conditional quantiles; h_bulk')
plt.show()

bti=bitcoin_threshold_index(X_BTC_reduced,Y_BTC_reduced,tau,m,start)

offset1=0
offset2=0

plt.scatter(F0_BTC_reduced[0,:], Y_BTC_reduced[0,:], color='blue', marker='o')
highest_indices_BTC_reduced = np.argsort(Y_BTC_reduced)[0,-bti:]
plt.scatter(F0_BTC_reduced[0,highest_indices_BTC_reduced], Y_BTC_reduced[0,highest_indices_BTC_reduced], color='red')
plt.plot(np.sort(F0_BTC_reduced[0,:])+offset1,  PP11_extreme[:,0], color='orange',label='alpha=0.95')
plt.plot(np.sort(F0_BTC_reduced[0,:])+offset2,  PP112_extreme[:,0], color='green',label='alpha=0.98')
plt.xlim(-0.02, 0.03) 
plt.ylim(-0.01, 0.22) 
plt.title('BTC_reduced; Univariate; h_extreme')
plt.legend()
plt.savefig('BTC_reduced_Univariate_h_extreme.pdf')  
plt.show()

plt.scatter(F0_BTC_reduced[0,:], Y_BTC_reduced[0,:], color='blue', marker='o')
highest_indices_BTC_reduced = np.argsort(Y_BTC_reduced)[0,-bti:]
plt.scatter(F0_BTC_reduced[0,highest_indices_BTC_reduced], Y_BTC_reduced[0,highest_indices_BTC_reduced], color='red')
plt.plot(np.sort(F0_BTC_reduced[0,:])+offset1,  PP11_extreme[:,2], color='orange',label='alpha=0.95')
plt.plot(np.sort(F0_BTC_reduced[0,:])+offset2,  PP112_extreme[:,2], color='green',label='alpha=0.98')
plt.xlim(-0.02, 0.03) 
plt.ylim(-0.01, 0.22) 
plt.title('BTC_reduced; Functional; h_extreme')
plt.legend()
plt.savefig('BTC_reduced_Functional_h_extreme.pdf')  
plt.show()

plt.scatter(F0_BTC_reduced[0,:], Y_BTC_reduced[0,:], color='blue', marker='o')
highest_indices_BTC_reduced = np.argsort(Y_BTC_reduced)[0,-bti:]
plt.scatter(F0_BTC_reduced[0,highest_indices_BTC_reduced], Y_BTC_reduced[0,highest_indices_BTC_reduced], color='red')
plt.plot(np.sort(F0_BTC_reduced[0,:])+offset1,  PP11_bulk[:,0], color='orange',label='alpha=0.95')
plt.plot(np.sort(F0_BTC_reduced[0,:])+offset2,  PP112_bulk[:,0], color='green',label='alpha=0.98')
plt.xlim(-0.02, 0.03) 
plt.ylim(-0.01, 0.22) 
plt.title('BTC_reduced; Univariate; h_bulk')
plt.legend()
plt.savefig('BTC_reduced_Univariate_h_bulk.pdf')  
plt.show()

plt.scatter(F0_BTC_reduced[0,:], Y_BTC_reduced[0,:], color='blue', marker='o')
highest_indices_BTC_reduced = np.argsort(Y_BTC_reduced)[0,-bti:]
plt.scatter(F0_BTC_reduced[0,highest_indices_BTC_reduced], Y_BTC_reduced[0,highest_indices_BTC_reduced], color='red')
plt.plot(np.sort(F0_BTC_reduced[0,:])+offset1,  PP11_bulk[:,2], color='orange',label='alpha=0.95')
plt.plot(np.sort(F0_BTC_reduced[0,:])+offset2,  PP112_bulk[:,2], color='green',label='alpha=0.98')
plt.xlim(-0.02, 0.03) 
plt.ylim(-0.01, 0.22) 
plt.title('BTC_reduced; Functional; h_bulk')
plt.legend()
plt.savefig('BTC_reduced_Functional_h_bulk.pdf')  
plt.show()



a=-0.01
b=0.03
Y2=2*F0_BTC_reduced+npr.uniform(0,0.01,size=(1,1095,))
P=plot_quantile_dimred_vs_func_2D_total(X_BTC_reduced,Y2,E0_BTC_reduced[0,:],E0_BTC_reduced[0,:],E0_BTC_reduced[0,:],alpha1,a,b,m,h_vector_bulk,h_func_vector_bulk,kernel) 
plt.scatter(F0_BTC_reduced[0,:],Y2[0,:])
X_plot = np.linspace(-0.01,0.03,1095)
plt.plot(X_plot,P[:,0],color='red')

plt.show() 

plt.scatter(F0_BTC_reduced[0,:],Y2[0,:])
plt.plot(P[:,0],color='red')

plt.show()

# %%
def hist_weight_extreme_2D(X_2D,Y,Y_sort_index, x_func,x,tau,m,start): # X_2D.shape = (n,d); x in \R; x_func \in H ie of shape (d,)
    d=x_func.shape[0] # Y of shape (N,n) and Y_sort_index = np.argsort(Y,axis=1)
    thresholdd = threshold(np.expand_dims(X_2D,axis=0),Y,Y_sort_index,tau,m,start)
    index_to_remove = np.where(Y<=thresholdd)
    X_extreme_2D=np.delete(X_2D,index_to_remove,axis=0)
    aux = (X_extreme_2D-x*x_func*np.ones(d))**2 # shape = (n2,d)
    out=np.zeros((X_extreme_2D.shape[0],2))
    out[:,0] = np.sqrt((1/d)*np.sum(aux,axis=1)) # shape = (n2,)
    out[:,1]= np.dot(X_extreme_2D,x_func)/d-x
    return out ### shape = (n2,)

def hist_weight_2D(X_2D,Y,Y_sort_index, x_func,x,tau,m,start): # X_2D.shape = (n,d); x in \R; x_func \in H ie of shape (d,)
    d=x_func.shape[0] # Y of shape (N,n) and Y_sort_index = np.argsort(Y,axis=1)
    aux = (X_2D-x*x_func*np.ones(d))**2 
    out=np.zeros((X_2D.shape[0],2))
    out[:,0] = np.sqrt((1/d)*np.sum(aux,axis=1)) 
    out[:,1]= np.dot(X_2D,x_func)/d-x
    return out ### shape = (n,)

@numba.njit(parallel=True, fastmath=False)
def hist_weight_extreme_2D_total(X_extreme_2D,x_func,a,b,m): 
    n2=X_extreme_2D.shape[0]
    d=X_extreme_2D.shape[1]
    x_grid = np.linspace(a,b,m)
    out=np.zeros((n2,m,2))
    for p in numba.prange(m):
        aux = (X_extreme_2D-x_grid[p]*x_func*np.ones(d))**2 # shape = (n2,d)
        out[:,p,0] = np.sqrt((1/d)*np.sum(aux,axis=1)) # shape = (n2,)
        out[:,p,1]= np.dot(X_extreme_2D,x_func)/d-x_grid[p]
    return out ### shape = (n2,)

@numba.njit(parallel=True, fastmath=False)
def hist_weight_2D_total(X_2D,x_func,a,b,m): 
    n=X_2D.shape[0]
    d=X_2D.shape[1]
    x_grid = np.linspace(a,b,m)
    out=np.zeros((n,m,2))
    for p in numba.prange(m):
        aux = (X_2D-x_grid[p]*x_func*np.ones(d))**2 # shape = (n,d)
        out[:,p,0] = np.sqrt((1/d)*np.sum(aux,axis=1)) # shape = (n,)
        out[:,p,1]= np.dot(X_2D,x_func)/d-x_grid[p]
    return out ### shape = (n,)

x=0
start = 14
m=X_BTC_reduced.shape[1]
a=-0.01
b=0.03
tau=-2
alpha1=0.90
alpha2=0.96
kernel=2 # Gaussian kernel
J=9
s1=150
s2=50

#####################################
X_2D = X_BTC_reduced[0,:,:]
Y_sort_index = np.argsort(Y_BTC_reduced,axis=1)
x_func = E0_BTC_reduced[0,:]
#############################
H_bulk=hist_weight_2D(X_2D,Y_BTC_reduced,Y_sort_index,x_func,x,tau,m,start)
H_total_bulk=hist_weight_2D_total(X_2D,x_func,a,b,m)
#############################
plt.hist(H_bulk[:,0],bins=100)
plt.title('Bulk univariate')
plt.show()
plt.hist(H_bulk[:,1],bins=100)
plt.title('Bulk functional')
plt.show()

#######################################
N=X_BTC_reduced.shape[0]
n=X_BTC_reduced.shape[1]
d=X_BTC_reduced.shape[2]

h_vector_extreme = (np.max(H_total_extreme[:,:,0],axis=0)-np.min(H_total_extreme[:,:,0],axis=0))/s1
h_func_vector_extreme = (np.max(H_total_extreme[:,:,1],axis=0)-np.min(H_total_extreme[:,:,1],axis=0))/s2
h_extreme=(np.max(H_extreme[:,0],axis=0)-np.min(H_extreme[:,0],axis=0))/s1
h_func_extreme=(np.max(H_extreme[:,1],axis=0)-np.min(H_extreme[:,1],axis=0))/s2
h_func_2D_extreme=np.transpose(np.outer(h_func_extreme*np.ones(n),np.ones(N))) # of shape (N,n) where A.shape = (n,); e.g., A=h_func*np.ones(n)

h_vector_bulk = (np.max(H_total_bulk[:,:,0],axis=0)-np.min(H_total_bulk[:,:,0],axis=0))/s1
h_func_vector_bulk = (np.max(H_total_bulk[:,:,1],axis=0)-np.min(H_total_bulk[:,:,1],axis=0))/s2
h_bulk=(np.max(H_bulk[:,0],axis=0)-np.min(H_bulk[:,0],axis=0))/s1
h_func_bulk=(np.max(H_bulk[:,1],axis=0)-np.min(H_bulk[:,1],axis=0))/s2
h_func_2D_bulk=np.transpose(np.outer(h_func_bulk*np.ones(n),np.ones(N))) # of shape (N,n) where A.shape = (n,); e.g., A=h_func*np.ones(n)

# Y|(X,dimred1)=(x*x_func,dimred1) (type 1) vs Y|(X,dimred2) = x (type 2) vs Y|X = x*x_func (type functional)
PP11_bulk=plot_quantile_dimred_vs_func_2D_total(X_BTC_reduced,Y_BTC_reduced,E0_BTC_reduced[0,:],E0_BTC_reduced[0,:],E0_BTC_reduced[0,:],alpha1,a,b,m,h_vector_bulk,h_func_vector_bulk,kernel) 
PP112_bulk=plot_quantile_dimred_vs_func_2D_total(X_BTC_reduced,Y_BTC_reduced,E0_BTC_reduced[0,:],E0_BTC_reduced[0,:],E0_BTC_reduced[0,:],alpha2,a,b,m,h_vector_bulk,h_func_vector_bulk,kernel) 


plt.plot(PP11_bulk[:,0])
plt.plot(PP11_bulk[:,1])
plt.plot(PP11_bulk[:,2])
plt.title('Conditional quantiles; h_bulk; alpha=0.90')
plt.show()

plt.plot(PP112_bulk[:,0])
plt.plot(PP112_bulk[:,1])
plt.plot(PP112_bulk[:,2])
plt.title('Conditional quantiles; h_bulk; alpha=0.96')
plt.show()

bti=bitcoin_threshold_index(X_BTC_reduced,Y_BTC_reduced,tau,m,start)

offset1=0
offset2=0


X_plot = np.linspace(-0.01,0.03,1095)

plt.scatter(F0_BTC_reduced[0,:], Y_BTC_reduced[0,:], color='blue', marker='o')
highest_indices_BTC_reduced = np.argsort(Y_BTC_reduced)[0,-bti:]
plt.scatter(F0_BTC_reduced[0,highest_indices_BTC_reduced], Y_BTC_reduced[0,highest_indices_BTC_reduced], color='red')
plt.plot(X_plot,  PP11_bulk[:,0], color='orange',label='alpha=0.90')
plt.plot(X_plot,  PP112_bulk[:,0], color='green',label='alpha=0.96')
plt.xlim(-0.02, 0.03) 
plt.ylim(-0.01, 0.22) 
plt.title('BTC_reduced; Univariate; h_bulk')
plt.legend()
plt.show()

plt.scatter(F0_BTC_reduced[0,:], Y_BTC_reduced[0,:], color='blue', marker='o')
highest_indices_BTC_reduced = np.argsort(Y_BTC_reduced)[0,-bti:]
plt.scatter(F0_BTC_reduced[0,highest_indices_BTC_reduced], Y_BTC_reduced[0,highest_indices_BTC_reduced], color='red')
plt.plot(X_plot,  PP11_bulk[:,2], color='orange',label='alpha=0.90')
plt.plot(X_plot,  PP112_bulk[:,2], color='green',label='alpha=0.96')
plt.xlim(-0.02, 0.03) 
plt.ylim(-0.01, 0.22) 
plt.title('BTC_reduced; Functional; h_bulk')
plt.legend()
plt.show()



a=-0.01
b=0.03
Y2=2*F0_BTC_reduced+npr.uniform(0,0.01,size=(1,1095,))
P=plot_quantile_dimred_vs_func_2D_total(X_BTC_reduced,Y2,E0_BTC_reduced[0,:],E0_BTC_reduced[0,:],E0_BTC_reduced[0,:],alpha2,a,b,m,h_vector_bulk,h_func_vector_bulk,kernel) 
plt.scatter(F0_BTC_reduced[0,:],Y2[0,:])
plt.plot(X_plot,P[:,0],color='red')
plt.show()

# %%
X1_2010_SP=pd.read_csv('DAT_ASCII_SPXUSD_M1_2010.csv',sep=';',header=None)
X1_2011_SP=pd.read_csv('DAT_ASCII_SPXUSD_M1_2011.csv',sep=';',header=None)
X1_2012_SP=pd.read_csv('DAT_ASCII_SPXUSD_M1_2012.csv',sep=';',header=None)
X1_2013_SP=pd.read_csv('DAT_ASCII_SPXUSD_M1_2013.csv',sep=';',header=None)
X1_2014_SP=pd.read_csv('DAT_ASCII_SPXUSD_M1_2014.csv',sep=';',header=None)
X1_2015_SP=pd.read_csv('DAT_ASCII_SPXUSD_M1_2015.csv',sep=';',header=None)
X1_2016_SP=pd.read_csv('DAT_ASCII_SPXUSD_M1_2016.csv',sep=';',header=None)
X1_2017_SP=pd.read_csv('DAT_ASCII_SPXUSD_M1_2017.csv',sep=';',header=None)
X1_2018_SP=pd.read_csv('DAT_ASCII_SPXUSD_M1_2018.csv',sep=';',header=None)

X1_2012_BTC=pd.read_csv('2012.csv')
X1_2018_BTC=pd.read_csv('2018.csv')
X1_2013_BTC=pd.read_csv('2013.csv')
X1_2014_BTC=pd.read_csv('2014.csv')
X1_2015_BTC=pd.read_csv('2015.csv')
X1_2016_BTC=pd.read_csv('2016.csv')
X1_2017_BTC=pd.read_csv('2017.csv')

####################### Change time format to match BTC datasets with SP/EUR/JP datasets (names of columns and timeformat)

X1_2012_BTC['date'] = pd.to_datetime(X1_2012_BTC['date'])
X1_2012_BTC['date'] = X1_2012_BTC['date'].dt.strftime('%Y%m%d %H%M%S')

X1_2013_BTC['date'] = pd.to_datetime(X1_2013_BTC['date'])
X1_2013_BTC['date'] = X1_2013_BTC['date'].dt.strftime('%Y%m%d %H%M%S')

X1_2014_BTC['date'] = pd.to_datetime(X1_2014_BTC['date'])
X1_2014_BTC['date'] = X1_2014_BTC['date'].dt.strftime('%Y%m%d %H%M%S')

X1_2015_BTC['date'] = pd.to_datetime(X1_2015_BTC['date'])
X1_2015_BTC['date'] = X1_2015_BTC['date'].dt.strftime('%Y%m%d %H%M%S')

X1_2016_BTC['date'] = pd.to_datetime(X1_2016_BTC['date'])
X1_2016_BTC['date'] = X1_2016_BTC['date'].dt.strftime('%Y%m%d %H%M%S')

X1_2017_BTC['date'] = pd.to_datetime(X1_2017_BTC['date'])
X1_2017_BTC['date'] = X1_2017_BTC['date'].dt.strftime('%Y%m%d %H%M%S')

X1_2018_BTC['date'] = pd.to_datetime(X1_2018_BTC['date'])
X1_2018_BTC['date'] = X1_2018_BTC['date'].dt.strftime('%Y%m%d %H%M%S')


X1_2010_SP = X1_2010_SP.rename(columns={ 0 : 'date'})
X1_2011_SP = X1_2011_SP.rename(columns={ 0 : 'date'})
X1_2012_SP = X1_2012_SP.rename(columns={ 0 : 'date'})
X1_2013_SP = X1_2013_SP.rename(columns={ 0 : 'date'})
X1_2014_SP = X1_2014_SP.rename(columns={ 0 : 'date'})
X1_2015_SP = X1_2015_SP.rename(columns={ 0 : 'date'})
X1_2016_SP = X1_2016_SP.rename(columns={ 0 : 'date'})
X1_2017_SP = X1_2017_SP.rename(columns={ 0 : 'date'})
X1_2018_SP = X1_2018_SP.rename(columns={ 0 : 'date'})

X1_2010_SP = X1_2010_SP.rename(columns={ 1 : 'open'})
X1_2011_SP = X1_2011_SP.rename(columns={ 1 : 'open'})
X1_2012_SP = X1_2012_SP.rename(columns={ 1 : 'open'})
X1_2013_SP = X1_2013_SP.rename(columns={ 1 : 'open'})
X1_2014_SP = X1_2014_SP.rename(columns={ 1 : 'open'})
X1_2015_SP = X1_2015_SP.rename(columns={ 1 : 'open'})
X1_2016_SP = X1_2016_SP.rename(columns={ 1 : 'open'})
X1_2017_SP = X1_2017_SP.rename(columns={ 1 : 'open'})
X1_2018_SP = X1_2018_SP.rename(columns={ 1 : 'open'})

X1_2010_SP = X1_2010_SP.rename(columns={ 2 : 'high'})
X1_2011_SP = X1_2011_SP.rename(columns={ 2 : 'high'})
X1_2012_SP = X1_2012_SP.rename(columns={ 2 : 'high'})
X1_2013_SP = X1_2013_SP.rename(columns={ 2 : 'high'})
X1_2014_SP = X1_2014_SP.rename(columns={ 2 : 'high'})
X1_2015_SP = X1_2015_SP.rename(columns={ 2 : 'high'})
X1_2016_SP = X1_2016_SP.rename(columns={ 2 : 'high'})
X1_2017_SP = X1_2017_SP.rename(columns={ 2 : 'high'})
X1_2018_SP = X1_2018_SP.rename(columns={ 2 : 'high'})

X1_2010_SP = X1_2010_SP.rename(columns={ 3 : 'low'})
X1_2011_SP = X1_2011_SP.rename(columns={ 3 : 'low'})
X1_2012_SP = X1_2012_SP.rename(columns={ 3 : 'low'})
X1_2013_SP = X1_2013_SP.rename(columns={ 3 : 'low'})
X1_2014_SP = X1_2014_SP.rename(columns={ 3 : 'low'})
X1_2015_SP = X1_2015_SP.rename(columns={ 3 : 'low'})
X1_2016_SP = X1_2016_SP.rename(columns={ 3 : 'low'})
X1_2017_SP = X1_2017_SP.rename(columns={ 3 : 'low'})
X1_2018_SP = X1_2018_SP.rename(columns={ 3 : 'low'})

X1_2010_SP = X1_2010_SP.rename(columns={ 4 : 'close'})
X1_2011_SP = X1_2011_SP.rename(columns={ 4 : 'close'})
X1_2012_SP = X1_2012_SP.rename(columns={ 4 : 'close'})
X1_2013_SP = X1_2013_SP.rename(columns={ 4 : 'close'})
X1_2014_SP = X1_2014_SP.rename(columns={ 4 : 'close'})
X1_2015_SP = X1_2015_SP.rename(columns={ 4 : 'close'})
X1_2016_SP = X1_2016_SP.rename(columns={ 4 : 'close'})
X1_2017_SP = X1_2017_SP.rename(columns={ 4 : 'close'})
X1_2018_SP = X1_2018_SP.rename(columns={ 4 : 'close'})


@numba.njit(parallel=True, fastmath=False) 
def mesh_time(X_conc,format): # X_conc = X_conc_SP for instance in minutes
    n = X_conc.shape[0]
    if format == '12h':
        d2=720
        n2 = int(n/d2)-1
    if format == '24h':
        d2=1440
        n2 = int(n/d2)
    out=np.zeros((n2,d2))
    for i in numba.prange(n2):
        out[i,:] = X_conc[d2*i:d2*(i+1)]
    return out

X1_2013_SP_BTC = pd.merge(X1_2013_SP, X1_2013_BTC, on='date', how='inner')
X1_2014_SP_BTC = pd.merge(X1_2014_SP, X1_2014_BTC, on='date', how='inner')
X1_2015_SP_BTC = pd.merge(X1_2015_SP, X1_2015_BTC, on='date', how='inner')
X1_2016_SP_BTC = pd.merge(X1_2016_SP, X1_2016_BTC, on='date', how='inner')
X1_2017_SP_BTC = pd.merge(X1_2017_SP, X1_2017_BTC, on='date', how='inner')

X_2013_SP_BTC = ((X1_2013_SP_BTC.values)[:,[4,9]]).astype(float)
X_2014_SP_BTC = ((X1_2014_SP_BTC.values)[:,[4,9]]).astype(float)
X_2015_SP_BTC = ((X1_2015_SP_BTC.values)[:,[4,9]]).astype(float)
X_2016_SP_BTC = ((X1_2016_SP_BTC.values)[:,[4,9]]).astype(float)
X_2017_SP_BTC = ((X1_2017_SP_BTC.values)[:,[4,9]]).astype(float)

X_conc_SP_BTC =np.append(X_2013_SP_BTC,X_2014_SP_BTC,axis=0)
X_conc_SP_BTC =np.append(X_conc_SP_BTC,X_2015_SP_BTC,axis=0)
X_conc_SP_BTC =np.append(X_conc_SP_BTC,X_2016_SP_BTC,axis=0)
X_conc_SP_BTC =np.append(X_conc_SP_BTC,X_2017_SP_BTC,axis=0)

X_conc_SP=X_conc_SP_BTC[:,0]
X_conc_BTC=X_conc_SP_BTC[:,1]

X_logreturn_conc2_SP=np.diff(np.log(X_conc_SP)) # shape -1
X_logreturn_conc_SP = np.append(X_logreturn_conc2_SP[0],X_logreturn_conc2_SP) # shape +1

X_logreturn_conc2_BTC=np.diff(np.log(X_conc_BTC)) # shape -1
X_logreturn_conc_BTC = np.append(X_logreturn_conc2_BTC[0],X_logreturn_conc2_BTC) # shape +1

SP_per_day=mesh_time(X_logreturn_conc_SP,'24h') # shape = (863, 1440) - 863 days with 1440 minutes recorded 
BTC_per_day=mesh_time(X_logreturn_conc_BTC,'24h') # shape = (863, 1440)

SP_per_day_even=SP_per_day[::2,:]
BTC_per_day_even=BTC_per_day[::2,:]

SP_per_day_odd=SP_per_day[1::2,:]
BTC_per_day_odd=BTC_per_day[1::2,:]

#Y_SP_BTC = np.max(SP_per_day_odd,axis=1)
#X_SP_BTC = BTC_per_day_even[:-1,:]

Y_SP_BTC = np.max(BTC_per_day_odd,axis=1)
X_SP_BTC = SP_per_day_even[:-1,:]

X_SP_BTC=np.expand_dims(X_SP_BTC,axis=0) # shape (N,n,d) with N=1;n=431;1440
Y_SP_BTC=np.expand_dims(Y_SP_BTC,axis=0) # shape (N,n,d) with N=1;n=431;1440

index_to_removee_SP_BTC = (Y_SP_BTC[0,:]).argsort()[-4]  
Y_SP_BTC_4 = np.expand_dims(np.delete(Y_SP_BTC[0,:],index_to_removee_SP_BTC),axis=0)
X_SP_BTC_4 = np.delete(X_SP_BTC,index_to_removee_SP_BTC,axis=1)

index_to_remove1_SP_BTC = np.argmax(Y_SP_BTC,axis=1)
Y_SP_BTC_new1 = np.expand_dims(np.delete(Y_SP_BTC[0,:],index_to_remove1_SP_BTC),axis=0)
X_SP_BTC_new1=np.delete(X_SP_BTC,index_to_remove1_SP_BTC,axis=1)
index_to_remove2_SP_BTC=np.argmax(Y_SP_BTC_new1,axis=1)
Y_SP_BTC_reduced=np.expand_dims(np.delete(Y_SP_BTC_new1,index_to_remove2_SP_BTC),axis=0)
X_SP_BTC_reduced=np.delete(X_SP_BTC_new1,index_to_remove2_SP_BTC,axis=1)

G_SP_BTC=get_hill_estimator(np.sort(Y_SP_BTC[0,:])[::-1])
index_min = 750
plt.plot(G_SP_BTC[:index_min])
plt.title('SP_BTC; Hill plot')
plt.show()

G_SP_BTC_reduced=get_hill_estimator(np.sort(Y_SP_BTC_reduced[0,:])[::-1])
plt.plot(G_SP_BTC_reduced[:index_min])
plt.title('SP_BTC_reduced; Hill plot')
plt.show()

G_SP_BTC_4=get_hill_estimator(np.sort(Y_SP_BTC_4[0,:])[::-1])
plt.plot(G_SP_BTC_4[:index_min])
plt.title('SP_BTC_without_4th_largest_element; Hill plot')
plt.show()

####################### Exponential Quantile-Quantile Plot
k=100
QQ=Exponential_QQ_Plot_1D(Y_SP_BTC,k)
x=QQ[:,0]
y=QQ[:,1]
res=linregress(QQ[:,0],QQ[:,1])
plt.plot(QQ[:,0], QQ[:,1], 'o')
plt.plot(QQ[:,0], res.intercept + res.slope*QQ[:,0], 'r')
plt.title('Exponential Quantile-Quantile Plot: SP_BTC;k=100')
plt.show()

k=100
QQ_reduced=Exponential_QQ_Plot_1D(Y_SP_BTC_reduced,k)
x=QQ_reduced[:,0]
y=QQ_reduced[:,1]
res_reduced=linregress(QQ_reduced[:,0],QQ_reduced[:,1])
plt.plot(QQ_reduced[:,0], QQ_reduced[:,1], 'o')
plt.plot(QQ_reduced[:,0], res_reduced.intercept + res_reduced.slope*QQ_reduced[:,0], 'r')
plt.title('Exponential Quantile-Quantile Plot: SP_BTC_reduced;k=100')
plt.show()

k=100
QQ_4=Exponential_QQ_Plot_1D(Y_SP_BTC_4,k)
x=QQ_4[:,0]
y=QQ_4[:,1]
res_4=linregress(QQ_4[:,0],QQ_4[:,1])
plt.plot(QQ_4[:,0], QQ_4[:,1], 'o')
plt.plot(QQ_4[:,0], res_4.intercept + res_4.slope*QQ_4[:,0], 'r')
plt.title('Exponential Quantile-Quantile Plot: SP_BTC_without_4;k=100')
plt.show()

############################### Correlation and Scatterplot


start=14
tau=1

C0_SP_BTC = bitcoin_concomittant_corr(X_SP_BTC,Y_SP_BTC,tau,200)
plt.plot(C0_SP_BTC)
plt.title('Correlation; tau=1, SP_BTC')
plt.show()

C0_SP_BTC_reduced = bitcoin_concomittant_corr(X_SP_BTC_reduced,Y_SP_BTC_reduced,tau,200)
plt.plot(C0_SP_BTC_reduced)
plt.title('Correlation; tau=1, SP_BTC_reduced')
plt.show()

C0_SP_BTC_4 = bitcoin_concomittant_corr(X_SP_BTC_4,Y_SP_BTC_4,tau,200)
plt.plot(C0_SP_BTC_4)
plt.title('Correlation; tau=1, SP_BTC without the 4th largest element')
plt.show()

m=int(X_SP_BTC.shape[1]/10) 
y_matrix_SP_BTC = bitcoin_threshold(X_SP_BTC,Y_SP_BTC,tau,m,start)
E0_SP_BTC=fepls(X_SP_BTC,Y_SP_BTC,y_matrix_SP_BTC,tau)
plt.plot(E0_SP_BTC[0,:])
plt.title('FEPLS SP_BTC')
plt.xticks(np.linspace(0, 1, 6))
plt.show()

m=int(X_SP_BTC_reduced.shape[1]/10) 
y_matrix_SP_BTC_reduced = bitcoin_threshold(X_SP_BTC_reduced,Y_SP_BTC_reduced,tau,m,start)
E0_SP_BTC_reduced=fepls(X_SP_BTC_reduced,Y_SP_BTC_reduced,y_matrix_SP_BTC_reduced,tau)
plt.plot(E0_SP_BTC_reduced[0,:])
plt.title('FEPLS SP_BTC_reduced')
plt.show()

m=int(X_SP_BTC_4.shape[1]/10) 
y_matrix_SP_BTC_4 = bitcoin_threshold(X_SP_BTC_4,Y_SP_BTC_4,tau,m,start)
E0_SP_BTC_4=fepls(X_SP_BTC_4,Y_SP_BTC_4,y_matrix_SP_BTC_4,tau)
plt.plot(E0_SP_BTC_4[0,:])
plt.title('FEPLS SP_BTC without the 4th largest element')
plt.show()

F0_SP_BTC=hatbeta_dot_X(X_SP_BTC,E0_SP_BTC)
bti = bitcoin_threshold_index(X_SP_BTC,Y_SP_BTC,tau,m,start)
F0_SP_BTC_reduced=hatbeta_dot_X(X_SP_BTC_reduced,E0_SP_BTC_reduced)
bti_reduced = bitcoin_threshold_index(X_SP_BTC_reduced,Y_SP_BTC_reduced,tau,m,start)
F0_SP_BTC_4=hatbeta_dot_X(X_SP_BTC_4,E0_SP_BTC_4)
bti_4 = bitcoin_threshold_index(X_SP_BTC_4,Y_SP_BTC_4,tau,m,start)

plt.scatter(F0_SP_BTC[0,:], Y_SP_BTC[0,:], color='blue', marker='o')
highest_indices_SP_BTC= np.argsort(Y_SP_BTC)[0,-bti:]
plt.scatter(F0_SP_BTC[0,highest_indices_SP_BTC], Y_SP_BTC[0,highest_indices_SP_BTC], color='red')
#plt.savefig('Scatter_SP500_5_tau_-2_v2.pdf') 
plt.title('SP_BTC')
plt.show()

plt.scatter(F0_SP_BTC_reduced[0,:], Y_SP_BTC_reduced[0,:], color='blue', marker='o')
highest_indices_SP_BTC_reduced= np.argsort(Y_SP_BTC_reduced)[0,-bti_reduced:]
plt.scatter(F0_SP_BTC_reduced[0,highest_indices_SP_BTC_reduced], Y_SP_BTC_reduced[0,highest_indices_SP_BTC_reduced], color='red')
#plt.savefig('Scatter_SP500_5_tau_-2_v2.pdf') 
plt.title('SP_BTC_reduced')
plt.show()


plt.scatter(F0_SP_BTC_4[0,:], Y_SP_BTC_4[0,:], color='blue', marker='o')
highest_indices_SP_BTC_4= np.argsort(Y_SP_BTC_4)[0,-bti_4:]
plt.scatter(F0_SP_BTC_4[0,highest_indices_SP_BTC_4], Y_SP_BTC_4[0,highest_indices_SP_BTC_4], color='red')
#plt.savefig('Scatter_SP500_5_tau_-2_v2.pdf')  
plt.title('SP_BTC_without the 4th largest element')
plt.show()

def hist_weight_extreme_2D(X_2D,Y,Y_sort_index, x_func,x,tau,m,start): # X_2D.shape = (n,d); x in \R; x_func \in H ie of shape (d,)
    d=x_func.shape[0] # Y of shape (N,n) and Y_sort_index = np.argsort(Y,axis=1)
    thresholdd = threshold(np.expand_dims(X_2D,axis=0),Y,Y_sort_index,tau,m,start)
    index_to_remove = np.where(Y<=thresholdd)
    X_extreme_2D=np.delete(X_2D,index_to_remove,axis=0)
    aux = (X_extreme_2D-x*x_func*np.ones(d))**2 # shape = (n2,d)
    out=np.zeros((X_extreme_2D.shape[0],2))
    out[:,0] = np.sqrt((1/d)*np.sum(aux,axis=1)) # shape = (n2,)
    out[:,1]= np.dot(X_extreme_2D,x_func)/d-x
    return out ### shape = (n2,)

def hist_weight_2D(X_2D,Y,Y_sort_index, x_func,x,tau,m,start): # X_2D.shape = (n,d); x in \R; x_func \in H ie of shape (d,)
    d=x_func.shape[0] # Y of shape (N,n) and Y_sort_index = np.argsort(Y,axis=1)
    aux = (X_2D-x*x_func*np.ones(d))**2 
    out=np.zeros((X_2D.shape[0],2))
    out[:,0] = np.sqrt((1/d)*np.sum(aux,axis=1)) 
    out[:,1]= np.dot(X_2D,x_func)/d-x
    return out ### shape = (n,)

@numba.njit(parallel=True, fastmath=False)
def hist_weight_extreme_2D_total(X_extreme_2D,x_func,a,b,m): 
    n2=X_extreme_2D.shape[0]
    d=X_extreme_2D.shape[1]
    x_grid = np.linspace(a,b,m)
    out=np.zeros((n2,m,2))
    for p in numba.prange(m):
        aux = (X_extreme_2D-x_grid[p]*x_func*np.ones(d))**2 # shape = (n2,d)
        out[:,p,0] = np.sqrt((1/d)*np.sum(aux,axis=1)) # shape = (n2,)
        out[:,p,1]= np.dot(X_extreme_2D,x_func)/d-x_grid[p]
    return out ### shape = (n2,)

@numba.njit(parallel=True, fastmath=False)
def hist_weight_2D_total(X_2D,x_func,a,b,m): 
    n=X_2D.shape[0]
    d=X_2D.shape[1]
    x_grid = np.linspace(a,b,m)
    out=np.zeros((n,m,2))
    for p in numba.prange(m):
        aux = (X_2D-x_grid[p]*x_func*np.ones(d))**2 # shape = (n,d)
        out[:,p,0] = np.sqrt((1/d)*np.sum(aux,axis=1)) # shape = (n,)
        out[:,p,1]= np.dot(X_2D,x_func)/d-x_grid[p]
    return out ### shape = (n,)

x=0
start = 14
m=X_SP_BTC_4.shape[1]
a=-0.00005*2
b=0.00025*2
tau=-2
alpha1=0.95
alpha2=0.98
kernel=2 # Gaussian kernel
J=9

#####################################
X_2D = X_SP_BTC_4[0,:,:]
Y_sort_index = np.argsort(Y_SP_BTC_4,axis=1)
x_func = E0_SP_BTC_4[0,:]
#############################
H_extreme=hist_weight_extreme_2D(X_2D,Y_SP_BTC_4,Y_sort_index,x_func,x,tau,m,start)
thresholdd = threshold(X_SP_BTC_4,Y_SP_BTC_4,Y_sort_index,tau,m,start)
index_to_remove = np.where(Y_SP_BTC_4<=thresholdd)
X_extreme_2D=np.delete(X_2D,index_to_remove,axis=0)
H_total_extreme=hist_weight_extreme_2D_total(X_extreme_2D,x_func,a,b,m)
#############################
plt.hist(H_extreme[:,0],bins=100)
plt.title('Extreme univariate')
plt.show()
plt.hist(H_extreme[:,1],bins=100)
plt.title('Extreme functional')
plt.show()
#############################
H_bulk=hist_weight_2D(X_2D,Y_SP_BTC_4,Y_sort_index,x_func,x,tau,m,start)
H_total_bulk=hist_weight_2D_total(X_2D,x_func,a,b,m)
#############################
plt.hist(H_bulk[:,0],bins=100)
plt.title('Bulk univariate')
plt.show()
plt.hist(H_bulk[:,1],bins=100)
plt.title('Bulk functional')
plt.show()

#######################################

N=X_SP_BTC_4.shape[0]
n=X_SP_BTC_4.shape[1]
d=X_SP_BTC_4.shape[2]

s1=1.2
s2=1.9

h_vector_extreme = (np.max(H_total_extreme[:,:,0],axis=0)-np.min(H_total_extreme[:,:,0],axis=0))/s1
h_func_vector_extreme = (np.max(H_total_extreme[:,:,1],axis=0)-np.min(H_total_extreme[:,:,1],axis=0))/s2
h_extreme=(np.max(H_extreme[:,0],axis=0)-np.min(H_extreme[:,0],axis=0))/s1
h_func_extreme=(np.max(H_extreme[:,1],axis=0)-np.min(H_extreme[:,1],axis=0))/s2
h_func_2D_extreme=np.transpose(np.outer(h_func_extreme*np.ones(n),np.ones(N))) # of shape (N,n) where A.shape = (n,); e.g., A=h_func*np.ones(n)

h_vector_bulk = (np.max(H_total_bulk[:,:,0],axis=0)-np.min(H_total_bulk[:,:,0],axis=0))/s1
h_func_vector_bulk = (np.max(H_total_bulk[:,:,1],axis=0)-np.min(H_total_bulk[:,:,1],axis=0))/s2
h_bulk=(np.max(H_bulk[:,0],axis=0)-np.min(H_bulk[:,0],axis=0))/s1
h_func_bulk=(np.max(H_bulk[:,1],axis=0)-np.min(H_bulk[:,1],axis=0))/s2
h_func_2D_bulk=np.transpose(np.outer(h_func_bulk*np.ones(n),np.ones(N))) # of shape (N,n) where A.shape = (n,); e.g., A=h_func*np.ones(n)

# Y|(X,dimred1)=(x*x_func,dimred1) (type 1) vs Y|(X,dimred2) = x (type 2) vs Y|X = x*x_func (type functional)
#PP1_extreme=plot_quantile_dimred_vs_func_2D(X_SP_BTC_4,Y_SP_BTC_4,E0_SP_BTC_4[0,:],E0_SP_BTC_4[0,:],E0_SP_BTC_4[0,:],alpha1,a,b,m,h_extreme,h_func_extreme,kernel) 
PP11_extreme=plot_quantile_dimred_vs_func_2D_total(X_SP_BTC_4,Y_SP_BTC_4,E0_SP_BTC_4[0,:],E0_SP_BTC_4[0,:],E0_SP_BTC_4[0,:],alpha1,a,b,m,h_vector_extreme,h_func_vector_extreme,kernel) 
PP112_extreme=plot_quantile_dimred_vs_func_2D_total(X_SP_BTC_4,Y_SP_BTC_4,E0_SP_BTC_4[0,:],E0_SP_BTC_4[0,:],E0_SP_BTC_4[0,:],alpha2,a,b,m,h_vector_extreme,h_func_vector_extreme,kernel) 

#PP2_extreme=plot_quantile_dimred_vs_func_2D(X_SP_BTC_4,Y_SP_BTC_4,beta_func2(d),beta_func2(d),beta_func2(d),alpha1,a,b,m,h_extreme,h_func_extreme,kernel) 
#PP22_extreme=plot_quantile_dimred_vs_func_2D_total(X_SP_BTC_4,Y_SP_BTC_4,beta_func2(d),beta_func2(d),beta_func2(d),alpha1,a,b,m,h_vector_extreme,h_func_vector_extreme,kernel) 

#PP1_bulk=plot_quantile_dimred_vs_func_2D(X_SP_BTC_4,Y_SP_BTC_4,E0_SP_BTC_4[0,:],E0_SP_BTC_4[0,:],E0_SP_BTC_4[0,:],alpha1,a,b,m,h_bulk,h_func_bulk,kernel) 
PP11_bulk=plot_quantile_dimred_vs_func_2D_total(X_SP_BTC_4,Y_SP_BTC_4,E0_SP_BTC_4[0,:],E0_SP_BTC_4[0,:],E0_SP_BTC_4[0,:],alpha1,a,b,m,h_vector_bulk,h_func_vector_bulk,kernel) 
PP112_bulk=plot_quantile_dimred_vs_func_2D_total(X_SP_BTC_4,Y_SP_BTC_4,E0_SP_BTC_4[0,:],E0_SP_BTC_4[0,:],E0_SP_BTC_4[0,:],alpha2,a,b,m,h_vector_bulk,h_func_vector_bulk,kernel) 
#PP2_bulk=plot_quantile_dimred_vs_func_2D(X_SP_BTC_4,Y_SP_BTC_4,beta_func2(d),beta_func2(d),beta_func2(d),alpha1,a,b,m,h_bulk,h_func_bulk,kernel) 
#PP22_bulk=plot_quantile_dimred_vs_func_2D_total(X_SP_BTC_4,Y_SP_BTC_4,beta_func2(d),beta_func2(d),beta_func2(d),alpha1,a,b,m,h_vector_bulk,h_func_vector_bulk,kernel) 

plt.plot(PP11_extreme[:,0])
plt.plot(PP11_extreme[:,1])
plt.plot(PP11_extreme[:,2])
plt.title('Conditional quantiles; h_extreme')
plt.show()
plt.plot(PP11_bulk[:,0])
plt.plot(PP11_bulk[:,1])
plt.plot(PP11_bulk[:,2])
plt.title('Conditional quantiles; h_bulk')
plt.show()

offset1=0
offset2=0

plt.scatter(F0_SP_BTC_4[0,:], Y_SP_BTC_4[0,:], color='blue', marker='o')
highest_indices_SP_BTC_4 = np.argsort(Y_SP_BTC_4)[0,-bti_4:]
plt.scatter(F0_SP_BTC_4[0,highest_indices_SP_BTC_4], Y_SP_BTC_4[0,highest_indices_SP_BTC_4], color='red')
plt.plot(np.sort(F0_SP_BTC_4[0,:])+offset1,  PP11_extreme[:,0], color='orange',label='alpha=0.95')
plt.plot(np.sort(F0_SP_BTC_4[0,:])+offset2,  PP112_extreme[:,0], color='green',label='alpha=0.98')
#plt.xlim(-0.02, 0.03) 
#plt.ylim(-0.01, 0.22) 
plt.title('SP_BTC_4; Univariate; h_extreme')
plt.legend()
plt.savefig('SP_BTC_4_Univariate_h_extreme.pdf')  
plt.show()

plt.scatter(F0_SP_BTC_4[0,:], Y_SP_BTC_4[0,:], color='blue', marker='o')
highest_indices_SP_BTC_4 = np.argsort(Y_SP_BTC_4)[0,-bti:]
plt.scatter(F0_SP_BTC_4[0,highest_indices_SP_BTC_4], Y_SP_BTC_4[0,highest_indices_SP_BTC_4], color='red')
plt.plot(np.sort(F0_SP_BTC_4[0,:])+offset1,  PP11_extreme[:,2], color='orange',label='alpha=0.95')
plt.plot(np.sort(F0_SP_BTC_4[0,:])+offset2,  PP112_extreme[:,2], color='green',label='alpha=0.98')
#plt.xlim(-0.02, 0.03) 
#plt.ylim(-0.01, 0.22) 
plt.title('SP_BTC_4; Functional; h_extreme')
plt.legend()
plt.savefig('SP_BTC_4_Functional_h_extreme.pdf')  
plt.show()

plt.scatter(F0_SP_BTC_4[0,:], Y_SP_BTC_4[0,:], color='blue', marker='o')
highest_indices_SP_BTC_4 = np.argsort(Y_SP_BTC_4)[0,-bti:]
plt.scatter(F0_SP_BTC_4[0,highest_indices_SP_BTC_4], Y_SP_BTC_4[0,highest_indices_SP_BTC_4], color='red')
plt.plot(np.sort(F0_SP_BTC_4[0,:])+offset1,  PP11_bulk[:,0], color='orange',label='alpha=0.95')
plt.plot(np.sort(F0_SP_BTC_4[0,:])+offset2,  PP112_bulk[:,0], color='green',label='alpha=0.98')
#plt.xlim(-0.02, 0.03) 
#plt.ylim(-0.01, 0.22) 
plt.title('SP_BTC_4; Univariate; h_bulk')
plt.legend()
plt.savefig('SP_BTC_4_Univariate_h_bulk.pdf')  
plt.show()

plt.scatter(F0_SP_BTC_4[0,:], Y_SP_BTC_4[0,:], color='blue', marker='o')
highest_indices_SP_BTC_4 = np.argsort(Y_SP_BTC_4)[0,-bti:]
plt.scatter(F0_SP_BTC_4[0,highest_indices_SP_BTC_4], Y_SP_BTC_4[0,highest_indices_SP_BTC_4], color='red')
plt.plot(np.sort(F0_SP_BTC_4[0,:])+offset1,  PP11_bulk[:,2], color='orange',label='alpha=0.95')
plt.plot(np.sort(F0_SP_BTC_4[0,:])+offset2,  PP112_bulk[:,2], color='green',label='alpha=0.98')
#plt.xlim(-0.02, 0.03) 
#plt.ylim(-0.01, 0.22) 
plt.title('SP_BTC_4; Functional; h_bulk')
plt.legend()
plt.savefig('SP_BTC_4_Functional_h_bulk.pdf')  
plt.show()
